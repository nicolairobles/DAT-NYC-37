# %%
import pandas as pd 

zillow_df = pd.read_csv("../lessons/lesson-03/assets/dataset/zillow-02-start.csv")

# %%
# %pwd
# Out:
# u'/Users/nicolai/code/datascience/DAT-NYC-37/Notes'

# %%
zillow_df.head() # top 5 
zillow_df.tail(5); # bottom 5

# %%
zillow_df.describe()
# Out:
#                  ID      Latitude     Longitude      SalePrice    BedCount  \
# count  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000  836.000000
# mean   1.591666e+08  3.775959e+07 -1.224348e+08  298264.042160    2.572967
# std    4.928856e+08  2.531078e+04  3.157521e+04  381637.332787    1.250891
# min    1.506347e+07  3.770844e+07 -1.225106e+08       1.000000    1.000000
# 25%    1.512042e+07  3.773848e+07 -1.224535e+08       1.350000         NaN
# 50%    1.516415e+07  3.776023e+07 -1.224317e+08       2.500000         NaN
# 75%    6.739436e+07  3.777999e+07 -1.224098e+08  718500.000000         NaN
# max    2.136214e+09  3.780543e+07 -1.223712e+08  999000.000000    9.000000
#
#         BathCount          Size       LotSize  BuiltInYear
# count  942.000000    967.000000    556.000000   975.000000
# mean     1.977548   1641.300931   2809.112770  1947.533333
# std      1.130334   1027.016175   1097.087521    38.021563
# ...

# %%
zillow_df.dtypes
# Out:
# ID                 int64
# Address           object
# Latitude           int64
# Longitude          int64
# DateOfSale        object
# SalePrice        float64
# SalePriceUnit     object
# IsAStudio         object
# BedCount         float64
# BathCount        float64
# Size             float64
# SizeUnit          object
# LotSize          float64
# LotSizeUnit       object
# BuiltInYear      float64
# dtype: object

# %%
zillow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
# ID               1000 non-null int64
# Address          1000 non-null object
# Latitude         1000 non-null int64
# Longitude        1000 non-null int64
# DateOfSale       1000 non-null object
# SalePrice        1000 non-null float64
# SalePriceUnit    1000 non-null object
# IsAStudio        986 non-null object
# BedCount         836 non-null float64
# BathCount        942 non-null float64
# Size             967 non-null float64
# SizeUnit         967 non-null object
# LotSize          556 non-null float64
# LotSizeUnit      556 non-null object
# BuiltInYear      975 non-null float64
# dtypes: float64(6), int64(3), object(6)
# memory usage: 117.3+ KB

# %%
zillow_df.columns
# Out:
# Index([u'ID', u'Address', u'Latitude', u'Longitude', u'DateOfSale',
#        u'SalePrice', u'SalePriceUnit', u'IsAStudio', u'BedCount', u'BathCount',
#        u'Size', u'SizeUnit', u'LotSize', u'LotSizeUnit', u'BuiltInYear'],
#       dtype='object')

# %%
zillow_df[["Address","Latitude","Longitude", "DateOfSale", "BedCount"]].head()
# Out:
#                                       Address  Latitude  Longitude DateOfSale  \
# 0   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856    12/4/15
# 1         740 Francisco St, San Francisco, CA  37804420 -122417389   11/30/15
# 2         819 Francisco St, San Francisco, CA  37803728 -122419055   11/12/15
# 3    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590   12/11/15
# 4  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509    1/15/16
#
#    BedCount
# 0       1.0
# 1       NaN
# 2       2.0
# 3       1.0
# 4       2.0

# %%
zillow_df[["Address","Latitude","Longitude", "DateOfSale", "BedCount"]].iloc[5:10]
# Out:
#                                       Address  Latitude  Longitude DateOfSale  \
# 5  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509   12/17/15
# 6   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531   12/15/15
# 7      2300 Leavenworth St, San Francisco, CA  37802408 -122417537    12/4/15
# 8     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704    1/14/16
# 9      1055 Lombard St # C, San Francisco, CA  37801873 -122418834   12/31/15
#
#    BedCount
# 5       2.0
# 6       1.0
# 7       3.0
# 8       NaN
# 9       2.0

# %%
new_zillow_df=zillow_df.set_index("ID")
new_zillow_df
# Out:
#                                                  Address  Latitude  Longitude  \
# ID
# 15063471       55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505             740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609             819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044        199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257      111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 15064295      111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 15064391       1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 15064536          2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064640         1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 15064669          1055 Lombard St # C, San Francisco, CA  37801873 -122418834
# 15065032      101 Lombard St APT 116E, San Francisco, CA  37803470 -122404090
# ...

# %%
new_zillow_df.index
# Out:
# Int64Index([  15063471,   15063505,   15063609,   15064044,   15064257,
#               15064295,   15064391,   15064536,   15064640,   15064669,
#             ...
#             2108546010, 2114498518, 2121221385, 2121978635, 2122992200,
#             2124214951, 2126960082, 2128308939, 2131957929, 2136213970],
#            dtype='int64', name=u'ID', length=1000)

# %%
new_zillow_df.loc[15063471]
# Out:
# Address          55 Vandewater St APT 9, San Francisco, CA
# Latitude                                          37805103
# Longitude                                       -122412856
# DateOfSale                                         12/4/15
# SalePrice                                           710000
# SalePriceUnit                                            $
# IsAStudio                                            False
# BedCount                                                 1
# BathCount                                              NaN
# Size                                                   550
# SizeUnit                                              sqft
# LotSize                                                NaN
# LotSizeUnit                                            NaN
# BuiltInYear                                           1980
# Name: 15063471, dtype: object

# %%
new_zillow_df.loc[15063471:15064669, ["Address", "Latitude", "Longitude"]]
# Out:
#                                              Address  Latitude  Longitude
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 15064391   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15064640     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
