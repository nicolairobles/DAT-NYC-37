# %%
# Unicode Handling
from __future__ import unicode_literals
import codecs

import numpy as np
import gensim

# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %%
# Loading the tweet data
filename = '../../assets/dataset/captured-tweets.txt'

tweets = []
for tweet in codecs.open(filename, 'r', encoding="utf-8"):
    tweets.append(tweet)

# Setting up spacy
nlp_toolkit = English()

# %% [markdown]
# ## In-Class Example

# %%
filename = "../../assets/dataset/captured-tweets.txt"

import codecs
tweets = []

for tweet in codecs.open(filename, "r", encoding="utf-8"):
    tweets.append(tweet)
    
tweets[:100]

import spacy
from spacy.en import English

sentence = u"I made a(n) Small Tourmaline in Paradise Island! https://t.co/"

english_parser = English()

# %%
result = english_parser(sentence)
type(result)

for token in result:
#     print "LEMMA", token.pos_
    print "LEMMA", token.lemma_

# %%
final = []

def lemmalize(sentence):
    result = english_parser(sentence)
    for (i, word) in enumerate(result): 
        print word
        if (word != word.lemma):
            final.append(word.lemma)
        else:
            final.append(word)
        print "\tParent: {}".format(word.head.lemma_)
        print "\tPhrase type: {}".format(word.dep_)
        print "\tKnown entity type: {}".format(word.ent_type_ if word.ent_type_ else 'n/a')
        print "\tLemma: {}".format(word.lemma_)
        
lemmalize(sentence)
final

# %%
tweets

# %%
# 1. Collection of tweets:
# List comprehension
transformed_tweets = [[token.lemma_ for token in english_parser(t) if not token.is_punct and not token.like_url] for t in tweets]

transformed_tweets
# Out:
# [[u'i',
#   u'make',
#   u'a(n',
#   u'small',
#   u'tourmaline',
#   u'in',
#   u'paradise',
#   u'island',
#   u'gameinsight',
#   u'androidgames',
#   u'android',
#   u'\n'],
#  [u'rt',
#   u'@purelovebeast',
#   u'-\u0e40\u0e0a\u0e47\u0e04\u0e23\u0e32\u0e22\u0e25\u0e30\u0e40\u0e2d\u0e35\u0e22\u0e14-',
#   u'27th',
#   u'birthday',
#   u'special',
#   u'goods',
#   u'3d',
#   u'yoseop',
#   u'usb',
#   u'\n'],
#  [u'\n'],
#  [u'@vigigu', u'google', u'it', u'simple', u'\n'],
#  [u'nerd', u'as', u'girl', u' ', u'\n'],
#  [u'leadcorp', u'media', u'@leadcorpmedia_', u' ', u'\n'],
#  [u'rt',
#   u'mackdrama1017',
#   u'chiemoney',
#   u'use',
#   u'google',
#   u'and',
#   u'learn',
#   u'how',
#   u'to',
#   u'\n'],
#  [u'@shaffieweru',
#   u'morning',
#   u'bro',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video',
#   u'i',
#   u'need',
#   u'yr',
#   u'help',
#   u'i',
#   u'be',
#   u'talented',
#   u'bt',
#   u'i',
#   u'lack',
#   u'a',
#   u'manager',
#   u'bro',
#   u'\n'],
#  [u'google', u'play', u'gift', u'card', u'code', u'\n'],
#  [u'claim',
#   u'your',
#   u'google',
#   u'play',
#   u'gift',
#   u'card',
#   u'code',
#   u'amazon',
#   u'itunes',
#   u'googl\u2026',
#   u'\n'],
#  [u'@rizsrug216',
#   u'@tpaquette_iid',
#   u'per',
#   u'sorry',
#   u'st.',
#   u'devs',
#   u'for',
#   u'the',
#   u'sport',
#   u'come',
#   u'to',
#   u'\n'],
#  [u'baseball', u'.039', u'\n'],
#  [u'football', u'.125', u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@politibunny',
#   u'@phillipjhill89',
#   u'you',
#   u'should',
#   u'go',
#   u'read',
#   u'a',
#   u'publish',
#   u'article',
#   u'that',
#   u'russell',
#   u'simmons',
#   u'write',
#   u'him',
#   u'google',
#   u'it',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'@moniimamz',
#   u'i',
#   u'know',
#   u'i',
#   u'saw',
#   u'it',
#   u'online',
#   u'like',
#   u'if',
#   u'u',
#   u'google',
#   u'the',
#   u'review',
#   u'for',
#   u'it',
#   u'\U0001f610',
#   u'\n'],
#  [u'rt',
#   u'@kamcb29',
#   u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'yayyyyy',
#   u'thanks',
#   u'for',
#   u'the',
#   u'follow',
#   u'@yeahhimafangirl',
#   u'\n'],
#  [u'i',
#   u'love',
#   u'your',
#   u'google',
#   u'plus',
#   u'page',
#   u'with',
#   u'the',
#   u'other',
#   u'girl',
#   u'\U0001f49c\U0001f606',
#   u'\n'],
#  [u'after',
#   u'i',
#   u'have',
#   u'google',
#   u'&amp',
#   u'read',
#   u'a',
#   u'ton',
#   u'of',
#   u'article',
#   u'on',
#   u'the',
#   u'same',
#   u'subject',
#   u'i',
#   u'remember',
#   u'i',
#   u'could',
#   u'have',
#   u'just',
#   u'search',
#   u'youtube',
#   u'for',
#   u'this',
#   u'shit',
#   u'\U0001f620',
#   u'\n'],
#  [u'week', u'2', u'power', u'rankings\U0001f608', u'\n'],
#  [u'rt',
#   u'@showerthoughtts',
#   u'apple',
#   u'have',
#   u'air',
#   u'amazon',
#   u'have',
#   u'fire',
#   u'google',
#   u'have',
#   u'earth',
#   u'why',
#   u'do',
#   u'not',
#   u'microsoft',
#   u'have',
#   u'water',
#   u'\n'],
#  [u'-look',
#   u'up',
#   u'on',
#   u'google',
#   u'mikexjeremy',
#   u'secretly-',
#   u'&lt;33',
#   u'@fnafschimdt,@mikeschmit10,]#senpaibot~',
#   u'\n'],
#  [u'rt',
#   u'@_silentbent_',
#   u'go',
#   u'support',
#   u'@dadeputy',
#   u'single',
#   u'it',
#   u"'",
#   u'okay',
#   u'feat',
#   u'@jaesongreen',
#   u'on',
#   u'itunes',
#   u'google\u2026',
#   u'\n'],
#  [u'hi', u'checkout', u'this', u'application', u'\n'],
#  [u'rt', u'@glotevo', u'nerd', u'as', u'girl', u' ', u'\n'],
#  [u'i',
#   u'be',
#   u'play',
#   u'my',
#   u'singing',
#   u'monsters',
#   u'check',
#   u'it',
#   u'out',
#   u'\n'],
#  [u'ever',
#   u'want',
#   u'to',
#   u'become',
#   u'a',
#   u'google',
#   u'small',
#   u'business',
#   u'advisor',
#   u'now',
#   u'you',
#   u'can',
#   u'\n'],
#  [u'check',
#   u'out',
#   u'@gcloudandroid',
#   u'never',
#   u'worry',
#   u'about',
#   u'lose',
#   u'your',
#   u'android',
#   u'device',
#   u'up',
#   u'to',
#   u'10',
#   u'gb',
#   u'free',
#   u'to',
#   u'backup',
#   u'\n'],
#  [u'top',
#   u'android',
#   u'apps',
#   u'without',
#   u'all',
#   u'the',
#   u'game',
#   u'reveal',
#   u'in',
#   u'hide',
#   u'google',
#   u'play',
#   u'store',
#   u'link',
#   u'android',
#   u'india',
#   u'\n'],
#  [u'rt',
#   u'@clashbabe',
#   u'th8',
#   u'50vs50',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'\n'],
#  [u'how',
#   u'to',
#   u'increase',
#   u'blog',
#   u'traffic',
#   u'with',
#   u'google',
#   u'plus',
#   u'blogging',
#   u'smm',
#   u'socialmedia',
#   u':officialchat\u2026',
#   u'\n'],
#  [u'relnews', u'\n'],
#  [u'                    ',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-the', u'daily', u'telegraph-', u'\n'],
#  [u'relnews', u'\n'],
#  [u'                    ',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-the', u'daily', u'telegraph-', u'\n'],
#  [u'new',
#   u'post',
#   u'google',
#   u'knowledge',
#   u'graph',
#   u'optimization',
#   u'strategies',
#   u'for',
#   u'the',
#   u'new',
#   u'year',
#   u'for',
#   u'infographic',
#   u'designers',
#   u'\n'],
#  [u'anyone',
#   u'else',
#   u'spend',
#   u'the',
#   u'entire',
#   u'time',
#   u'drive',
#   u'try',
#   u'to',
#   u'beat',
#   u'the',
#   u'original',
#   u'arrival',
#   u'time',
#   u'estimate',
#   u'from',
#   u'google',
#   u'maps',
#   u'\U0001f643',
#   u'\n'],
#  [u'design', u'font', u'of', u'the', u'day', u'mecka', u'design', u'\n'],
#  [u'google',
#   u'you',
#   u'have',
#   u'fail',
#   u'me',
#   u'for',
#   u'the',
#   u'first',
#   u'time',
#   u'why',
#   u'can',
#   u'not',
#   u'you',
#   u'tell',
#   u'me',
#   u'what',
#   u'these',
#   u'crystal',
#   u'be',
#   u'inside',
#   u'my',
#   u'plum',
#   u'\n'],
#  [u'rt', u'@rougek68', u'on', u'the', u'meaning', u'of', u'fascism', u'\n'],
#  [u'usa', u'israel', u'\n'],
#  [u'we', u"'re", u'all', u'fascist', u'now', u'\n'],
#  [u'time', u'u', u'kno\u2026', u'\n'],
#  [u'google', u'team2pm', u'\n'],
#  [u'rt',
#   u'@clashbabe',
#   u'th8',
#   u'50vs50',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'\n'],
#  [u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'compliment',
#   u'you',
#   u'\n'],
#  [u'rt',
#   u'@_rachaelmcclung',
#   u'brain',
#   u'go',
#   u'to',
#   u'sleep',
#   u'its',
#   u'10',
#   u'pm',
#   u'you',
#   u'now',
#   u'have',
#   u'a',
#   u'decent',
#   u'8',
#   u'hour',
#   u'of',
#   u'sleep',
#   u'\n'],
#  [u'me',
#   u'stay',
#   u'up',
#   u'to',
#   u'google',
#   u'different',
#   u'food',
#   u'recipe',
#   u'for\u2026',
#   u'\n'],
#  [u'rt',
#   u'google',
#   u'android',
#   u'n',
#   u'will',
#   u'not',
#   u'use',
#   u'oracle',
#   u"'s",
#   u' ',
#   u'java',
#   u'apis',
#   u' ',
#   u'gunjanraik',
#   u'\n'],
#  [u'rt',
#   u'android',
#   u'application',
#   u'relate',
#   u'to',
#   u'google',
#   u'map',
#   u'2',
#   u'by',
#   u'nsatheeshk',
#   u'need',
#   u'to',
#   u'update',
#   u'the',
#   u'android',
#   u'mobil',
#   u'\n'],
#  [u'my',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8',
#   u'out',
#   u'there',
#   u'\n'],
#  [u'oldrocks',
#   u'structuresleftbehind',
#   u'predeluge',
#   u'ancient',
#   u'microsculpture',
#   u'to',
#   u'massive',
#   u'face',
#   u'&amp',
#   u'shape',
#   u'iconography',
#   u'remain',
#   u'\n'],
#  [u'@imbruedjoint',
#   u'hector',
#   u'have',
#   u'softly',
#   u'tilt',
#   u'his',
#   u'head',
#   u'towards',
#   u'stuart',
#   u'in',
#   u'a',
#   u'confused',
#   u'sort',
#   u'of',
#   u'way',
#   u'what',
#   u"'",
#   u'google',
#   u'he',
#   u'could',
#   u'not',
#   u'possibly',
#   u'know',
#   u'what',
#   u'\n'],
#  [u'good',
#   u'domain',
#   u'possibility',
#   u'www',
#   u'west',
#   u'virginia',
#   u'its',
#   u'trending',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'here',
#   u'man',
#   u'@thereallogs1996',
#   u'when',
#   u'you',
#   u'talk',
#   u'about',
#   u'how',
#   u'the',
#   u'cubs',
#   u'win',
#   u'last',
#   u'year',
#   u' ',
#   u'\n'],
#  [u'google',
#   u'knowledge',
#   u'graph',
#   u'optimization',
#   u'strategies',
#   u'for',
#   u'the',
#   u'new',
#   u'year',
#   u'for',
#   u'infographic',
#   u'  ',
#   u'designer',
#   u'\n'],
#  [u'lebanonhashtag',
#   u'rt',
#   u'probrandz',
#   u'facebook',
#   u'open',
#   u'sources',
#   u'artificial',
#   u'intelligence',
#   u'servers',
#   u'before',
#   u'google',
#   u'|',
#   u're/code',
#   u'\n'],
#  [u'di\u2026', u'\n'],
#  [u'@r0thejan',
#   u'earn',
#   u'free',
#   u'google',
#   u'play',
#   u'and',
#   u'many',
#   u'more',
#   u'giftcards',
#   u'at',
#   u'our',
#   u'fresh',
#   u'publish',
#   u'website',
#   u'\n'],
#  [u'kalguntuku',
#   u'rt',
#   u'bunnymiilk',
#   u'rt',
#   u'30seclovelive',
#   u'rt',
#   u'to',
#   u'win',
#   u'30',
#   u'second',
#   u'of',
#   u'love',
#   u'live',
#   u'5k',
#   u'follower',
#   u'giveaway',
#   u'1',
#   u'$',
#   u'25',
#   u'itunes/google',
#   u'play',
#   u'gift',
#   u'ca\u2026',
#   u'\n'],
#  [u'rt',
#   u'@fortunemagazine',
#   u'here',
#   u'\u2019',
#   u'how',
#   u'google',
#   u'be',
#   u'take',
#   u'on',
#   u'uber',
#   u'in',
#   u'2016',
#   u'\n'],
#  [u'minecraft',
#   u'i',
#   u'google',
#   u'natural',
#   u'arch',
#   u'and',
#   u'a',
#   u'minecraft',
#   u'image',
#   u'pop',
#   u'up',
#   u'for',
#   u'a',
#   u'real',
#   u'geographical',
#   u'scenic',
#   u'spot',
#   u'by',
#   u'skandal\u2026',
#   u'\n'],
#  [u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'abo\u2026',
#   u'\n'],
#  [u'what',
#   u'each',
#   u'state',
#   u'google',
#   u'd',
#   u'more',
#   u'than',
#   u'me',
#   u'love',
#   u'picoftheday',
#   u'follow',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'google',
#   u'a',
#   u'wolf',
#   u'hybrid',
#   u'its',
#   u'my',
#   u'future',
#   u'dog',
#   u'\n'],
#  [u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'unlock',
#   u'a',
#   u'new',
#   u'area',
#   u'of',
#   u'my',
#   u'island',
#   u'gameinsight',
#   u'android',
#   u'androidgames',
#   u'\n'],
#  [u'get',
#   u'it',
#   u'google',
#   u"'s",
#   u'late',
#   u'free',
#   u'android',
#   u'wallpaper',
#   u'show',
#   u'useful',
#   u'phone',
#   u'android',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'reach',
#   u'level',
#   u'28',
#   u'i',
#   u'earn',
#   u'  ',
#   u'$',
#   u'123000',
#   u'and',
#   u'\u20ac3',
#   u'gameinsight',
#   u'androidgames',
#   u'android',
#   u'\n'],
#  [u'make',
#   u'sure',
#   u'your',
#   u'siwe',
#   u'ishkeeping',
#   u'xsers',
#   u'mn',
#   u'thxir',
#   u'prefer',
#   u'ver|ion',
#   u' ',
#   u'fkyourmwebsite',
#   u'for',
#   u'tceir',
#   u'entule',
#   u'vtsiq',
#   u'google',
#   u'webmcstervkx',
#   u'\n'],
#  [u'rt',
#   u'@ladybirdcoc',
#   u'my',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8',
#   u'out',
#   u'there',
#   u'\n'],
#  [u'nfl',
#   u'marshawnlynch',
#   u'2013',
#   u'nfc',
#   u'champ',
#   u'game',
#   u'marshawn',
#   u'lynch',
#   u'touchdown',
#   u'run',
#   u'seattle',
#   u'seahawks',
#   u'8x10',
#   u'photo',
#   u'seahawks',
#   u'google',
#   u'\n'],
#  [u'@chocolateluvah',
#   u'completely',
#   u'agree',
#   u'it',
#   u"'",
#   u'kill',
#   u'me',
#   u'not',
#   u'to',
#   u'google',
#   u'the',
#   u'case',
#   u'haha',
#   u'\n'],
#  [u'@jeddzn',
#   u'@ivanofficial__',
#   u'@picardonoel',
#   u'what',
#   u'',
#   u'that',
#   u'do',
#   u'nt',
#   u'ask',
#   u'me',
#   u'to',
#   u'google',
#   u'it',
#   u'\n'],
#  [u'rt',
#   u'@seosanjayupadhy',
#   u'alt',
#   u'+',
#   u'6',
#   u'....\u2660',
#   u'..s\xacpade',
#   u'alt',
#   u'+',
#   u'5',
#   u'....\u2663',
#   u'\xacclub',
#   u'alt',
#   u'+',
#   u'3',
#   u'\xacheart',
#   u'alt',
#   u'+',
#   u'4',
#   u'....\u2666',
#   u'\xacdiamond\u2026',
#   u'htt\u2026',
#   u'\n'],
#  [u'rt',
#   u'@chrismessina',
#   u'tell',
#   u'me',
#   u'that',
#   u'zuck',
#   u'be',
#   u'not',
#   u'plan',
#   u'to',
#   u'take',
#   u'on',
#   u'google',
#   u'with',
#   u'messenger',
#   u'convcomm',
#   u' ',
#   u'\n'],
#  [u'second',
#   u'when',
#   u'i',
#   u'be',
#   u'tweet',
#   u'i',
#   u'have',
#   u'always',
#   u'get',
#   u'my',
#   u'google',
#   u'docs',
#   u'open',
#   u'as',
#   u'well',
#   u'amwriting',
#   u'\n'],
#  [u'rt',
#   u'showerthoughtts',
#   u'apple',
#   u'have',
#   u'air',
#   u'amazon',
#   u'have',
#   u'fire',
#   u'google',
#   u'have',
#   u'earth',
#   u'why',
#   u'do',
#   u'not',
#   u'm\u2026',
#   u'\n'],
#  [u'@luckyberry96',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'@victoria_stee',
#   u'u',
#   u'+google',
#   u"'s",
#   u'instruction',
#   u'just',
#   u'save',
#   u'my',
#   u'life\U0001f618',
#   u'\n'],
#  [u'rt',
#   u'@kunalchoudhary_',
#   u'pathankot',
#   u'attack',
#   u'youth',
#   u'congress',
#   u'member',
#   u'burn',
#   u'sharifs',
#   u'effigy',
#   u'in',
#   u'bhopal',
#   u'@indiatoday',
#   u'\n'],
#  [u'@rajabrar\u2026', u'\n'],
#  [u'also',
#   u'here',
#   u'it',
#   u'be',
#   u'my',
#   u'revamped',
#   u'and',
#   u'much',
#   u'better',
#   u'got7',
#   u'primer',
#   u'share',
#   u'our',
#   u'boy',
#   u'with',
#   u'the',
#   u'world',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'new',
#   u'mobile',
#   u'apps',
#   u'on',
#   u'playstore',
#   u'android',
#   u'god',
#   u'of',
#   u'rome',
#   u'cut',
#   u'the',
#   u'rope',
#   u'gun',
#   u'simulator',
#   u'kitwall',
#   u'etc',
#   u'.check',
#   u'more',
#   u'on',
#   u'\n'],
#  [u'any', u'other', u'taker', u'\n'],
#  [u'googleexpertuk',
#   u'google',
#   u'support',
#   u'swedish',
#   u'chef',
#   u'from',
#   u'the',
#   u'muppets',
#   u'muppetsstudio',
#   u'internet',
#   u'\n'],
#  [u'eco', u'100', u'wk', u'10', u'chapter', u'18', u'homework', u'\n'],
#  [u'@winterfnmute665',
#   u'@rt_america',
#   u'look',
#   u'up',
#   u'militia',
#   u'too',
#   u'second',
#   u'definition',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'these',
#   u'term',
#   u'no',
#   u'matter',
#   u'how',
#   u'bad',
#   u'you',
#   u'want',
#   u'to',
#   u'\n'],
#  [u'kalguntuku',
#   u'rt',
#   u'bunnymiilk',
#   u'rt',
#   u'30seclovelive',
#   u'rt',
#   u'to',
#   u'win',
#   u'30',
#   u'second',
#   u'of',
#   u'love',
#   u'live',
#   u'5k',
#   u'follower',
#   u'giveaway',
#   u'1',
#   u'$',
#   u'25',
#   u'i\u2026',
#   u'\n'],
#  [u'@ohitsmrcreeper',
#   u'@sapphireginger',
#   u'oh',
#   u'thank',
#   u'god',
#   u'google',
#   u'translate',
#   u'be',
#   u'wrong',
#   u'\n'],
#  [u'rt',
#   u'@carlaliones',
#   u'\u2714tweetsheet\u27a1petitions',
#   u'part',
#   u'3\u2714',
#   u'support',
#   u'the',
#   u'fight',
#   u'against',
#   u'dog&amp;cat',
#   u'meatindustry',
#   u'in',
#   u'southkorea',
#   u'http\u2026',
#   u'\n'],
#  [u'google', u'maps', u'\n'],
#  [u'@xen_game',
#   u'google',
#   u'do',
#   u'not',
#   u'say',
#   u'what',
#   u'5',
#   u'out',
#   u'7',
#   u'mean',
#   u'why',
#   u'not',
#   u'7',
#   u'out',
#   u'of',
#   u'7',
#   u'\n'],
#  [u'@makingstarwar',
#   u'ugh',
#   u'the',
#   u'right',
#   u'sign',
#   u'mess',
#   u'up',
#   u'the',
#   u'link',
#   u'google',
#   u'force',
#   u'awaken',
#   u'70mm',
#   u'and',
#   u'the',
#   u'imax',
#   u'link',
#   u'should',
#   u'send',
#   u'you',
#   u'there',
#   u'\n'],
#  [u'rt',
#   u'@dinowoowife',
#   u'my',
#   u'bts',
#   u'2nd',
#   u'muster',
#   u'slogan',
#   u'\ub450\uadfc\uac74',
#   u'by',
#   u'visual',
#   u'shock',
#   u'@vshock1230',
#   u'\n'],
#  [u'lebanonhashtag',
#   u'rt',
#   u'probrandz',
#   u'facebook',
#   u'open',
#   u'sources',
#   u'artificial',
#   u'intelligence',
#   u'servers',
#   u'before',
#   u'google',
#   u'|',
#   u're/code',
#   u'\n'],
#  [u'di\u2026', u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'paypal',
#   u'me',
#   u'be',
#   u'so',
#   u'infuriating',
#   u'but',
#   u'i',
#   u'be',
#   u'use',
#   u'it',
#   u'anyway',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'ford',
#   u'add',
#   u'apple',
#   u'carplay',
#   u'and',
#   u'android',
#   u'auto',
#   u'to',
#   u'sync',
#   u'3',
#   u'google',
#   u'|',
#   u'\n'],
#  [u'best',
#   u'colour',
#   u'for',
#   u'zodiac',
#   u'sign',
#   u'in',
#   u'year',
#   u'2016',
#   u'\n'],
#  [u'\n'],
#  [u'@shaffieweru',
#   u'hi',
#   u'bro',
#   u'i',
#   u'need',
#   u'your',
#   u'help',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video..can',
#   u'you',
#   u'manage',
#   u'me',
#   u'bro',
#   u'\n'],
#  [u'try',
#   u'twitgrow',
#   u'for',
#   u'twitter',
#   u'get',
#   u'1000+',
#   u'real',
#   u'follower',
#   u'retweets',
#   u'and',
#   u'favorite',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'rt',
#   u'@lw',
#   u'how',
#   u'to',
#   u'be',
#   u'the',
#   u'person',
#   u'who',
#   u'never',
#   u'miss',
#   u'a',
#   u'deadline',
#   u'\n'],
#  [u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'abo\u2026',
#   u'\n'],
#  [u'rt',
#   u'@dinowoowife',
#   u'my',
#   u'jimin',
#   u'2016',
#   u'rise',
#   u'stock',
#   u'sale',
#   u'by',
#   u'miningful',
#   u'moment',
#   u'@miningfulmoment',
#   u'\u2665',
#   u'\n'],
#  [u'creativitybooster',
#   u'communicate',
#   u'stupid',
#   u'affiliate',
#   u'at',
#   u'google',
#   u'top',
#   u'10',
#   u'idea',
#   u'growthhacking',
#   u'blogging',
#   u'\n'],
#  [u'radio',
#   u'top40',
#   u'now',
#   u'play',
#   u'shut',
#   u'up',
#   u'stormzy',
#   u'apps',
#   u'apple',
#   u'google',
#   u'\n'],
#  [u'will',
#   u'google',
#   u'do',
#   u'one',
#   u'of',
#   u'those',
#   u'semantically',
#   u'aware',
#   u'auto',
#   u'answer',
#   u'if',
#   u'i',
#   u'search',
#   u'rza',
#   u'elo',
#   u'do',
#   u'not',
#   u'wanna',
#   u'be',
#   u'disappoint',
#   u'\n'],
#  [u'just',
#   u'like',
#   u'new',
#   u'college',
#   u'student',
#   u'be',
#   u'at',
#   u'risk',
#   u'for',
#   u'the',
#   u'freshman',
#   u'15',
#   u'google',
#   u'employee',
#   u'joke',
#   u'about',
#   u'the',
#   u'google',
#   u'15',
#   u'from',
#   u'all',
#   u'the',
#   u'snaks',
#   u'available',
#   u'\n'],
#  [u'me', u'af', u'\U0001f602\U0001f602\U0001f602', u'\n'],
#  [u'spare',
#   u'mark',
#   u'as',
#   u'respect',
#   u'the',
#   u'google',
#   u'android',
#   u'scum',
#   u'yourself',
#   u'april',
#   u'au',
#   u'pair',
#   u'self',
#   u'skacv',
#   u'\n'],
#  [u'google',
#   u'cardboard',
#   u'used',
#   u'by',
#   u'surgeon',
#   u'to',
#   u'perform',
#   u'heart',
#   u'surgery',
#   u'and',
#   u'saves',
#   u'a',
#   u'life',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'spend',
#   u'money',
#   u'saves',
#   u'you',
#   u'time',
#   u'and',
#   u'earns',
#   u'you',
#   u'more',
#   u'money',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'this',
#   u'house',
#   u'be',
#   u'sell',
#   u'dirt',
#   u'cheap',
#   u'the',
#   u'google',
#   u'maps',
#   u'picture',
#   u'explains',
#   u'exactly',
#   u'why',
#   u'\n'],
#  [u'google', u'have', u'no', u'chill', u'\n'],
#  [u'rt',
#   u'@got7style',
#   u'b2gether',
#   u'got7',
#   u'with',
#   u'b',
#   u'connect',
#   u'bracelet',
#   u'\n'],
#  [u'jb', u' ', u'jackson', u' ', u'teamgot7', u'got7style', u'\n'],
#  [u'\n'],
#  [u'woman', u'rise', u'in', u'hp', u'panchayat', u'politics', u'hp', u'\n'],
#  [u'police',
#   u'condemn',
#   u'facebook',
#   u'comment',
#   u'on',
#   u'mount',
#   u'maunganui',
#   u'new',
#   u'year',
#   u"'s",
#   u'eve',
#   u'page',
#   u'facebook',
#   u'\n'],
#  [u'wonder',
#   u'which',
#   u'food',
#   u'be',
#   u'healthier',
#   u'google',
#   u'have',
#   u'a',
#   u'tool',
#   u'for',
#   u'\n'],
#  [u'rt',
#   u'@f396',
#   u'iran',
#   u'blame',
#   u'america',
#   u'britain',
#   u'and',
#   u'zionist',
#   u'for',
#   u'nimr',
#   u'execution',
#   u'via',
#   u'\n'],
#  [u'@trp_takumi', u'reply', u'\n'],
#  [u'\n'],
#  [u'gunakan', u'lah', u'google', u'translate', u'lol', u'xd', u'\n'],
#  [u'lifehacker',
#   u'run',
#   u'windows',
#   u'on',
#   u'your',
#   u'mac',
#   u'virtualbox',
#   u'vs',
#   u'vmware',
#   u'fusion',
#   u'vs',
#   u'parallels',
#   u'\n'],
#  [u'the',
#   u'polar',
#   u'bears',
#   u'movie',
#   u'&amp',
#   u'tv',
#   u'on',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'become',
#   u'a',
#   u'google',
#   u'small',
#   u'business',
#   u'expert',
#   u'advisor',
#   u' ',
#   u'inboundmarketing',
#   u'feedly',
#   u'\n'],
#  [u'gang',
#   u'knock',
#   u'down',
#   u'cane',
#   u'grove',
#   u'man',
#   u'then',
#   u'beat',
#   u'him',
#   u'to',
#   u'death',
#   u'beat',
#   u'\n'],
#  [u'ohio',
#   u'state',
#   u'basketball',
#   u'win',
#   u'sixth',
#   u'straight',
#   u'beat',
#   u'illinois',
#   u'75',
#   u'73',
#   u'beat',
#   u'\n'],
#  [u'rt',
#   u'@newsycombinator',
#   u'google',
#   u'hp',
#   u'oracle',
#   u'join',
#   u'risc',
#   u'v',
#   u'open',
#   u'source',
#   u'processor',
#   u'core',
#   u'gain',
#   u'traction',
#   u'\n'],
#  [u'@_queenlioness_',
#   u'@justinrgrrb',
#   u'@mcdonald_wes',
#   u'sweet',
#   u'de',
#   u'lights',
#   u'bakery',
#   u'inc',
#   u'&lt;----',
#   u'this',
#   u'place',
#   u'google',
#   u'it',
#   u'a++++++',
#   u'\n'],
#  [u'rt',
#   u'@f396',
#   u'saudi',
#   u'arabia',
#   u'sever',
#   u'diplomatic',
#   u'tie',
#   u'with',
#   u'iran',
#   u'over',
#   u'embassy',
#   u'fire',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'people',
#   u'un',
#   u'follow',
#   u'you',
#   u'on',
#   u'social',
#   u'media',
#   u'platforms',
#   u' ',
#   u'quick',
#   u'cash',
#   u'\n'],
#  [u'@mrkenneyy',
#   u'i',
#   u'saw',
#   u'ur',
#   u'tweet',
#   u'no',
#   u'need',
#   u'for',
#   u'google',
#   u'lol',
#   u'it',
#   u"'",
#   u'a',
#   u'very',
#   u'large',
#   u'dog',
#   u'\n'],
#  [u'new',
#   u'google',
#   u'chat',
#   u'app',
#   u'could',
#   u'destroy',
#   u'facebook',
#   u'messenger',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'@lexicaaan',
#   u'me',
#   u'af',
#   u'\U0001f602\U0001f602\U0001f602',
#   u'\n'],
#  [u'radio',
#   u'90',
#   u'juice',
#   u'now',
#   u'play',
#   u'breathe',
#   u'radio',
#   u'edit',
#   u'midge',
#   u'ure',
#   u'apps',
#   u'apple',
#   u'google',
#   u'\n'],
#  [u'@sebast_lj',
#   u'@mcfaul',
#   u'@inna4848',
#   u'cause',
#   u'google',
#   u'translate',
#   u'it',
#   u'as',
#   u'return',
#   u'to',
#   u'california',
#   u'\n'],
#  [u'my',
#   u'google',
#   u'play',
#   u'account',
#   u'make',
#   u'me',
#   u'realize',
#   u'i',
#   u'be',
#   u'a',
#   u'dysfunctional',
#   u'teen',
#   u'with',
#   u'deep',
#   u'emotional',
#   u'scar',
#   u'\n'],
#  [u'late',
#   u'update',
#   u'brings',
#   u'new',
#   u'skills',
#   u'to',
#   u'the',
#   u'amazonecho',
#   u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@f396',
#   u'iran',
#   u'have',
#   u'a',
#   u'long',
#   u'record',
#   u'in',
#   u'attack',
#   u'foreign',
#   u'diplomatic',
#   u'mission',
#   u'saudi',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'a\u2026',
#   u'\n'],
#  [u'rt',
#   u'masterminddbs',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'al\u2026',
#   u'\n'],
#  [u'just', u'like', u'real', u'life', u'\n'],
#  [u'i',
#   u'like',
#   u'a',
#   u'@youtube',
#   u'video',
#   u'10',
#   u'thing',
#   u'you',
#   u'should',
#   u'never',
#   u'google',
#   u'warning',
#   u'gross',
#   u'\n'],
#  [u'here',
#   u'be',
#   u'what',
#   u'happen',
#   u'to',
#   u'@_snat',
#   u'when',
#   u'he',
#   u'can',
#   u'not',
#   u'access',
#   u'google',
#   u'translate',
#   u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@kappa_kappa',
#   u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'c\u2026',
#   u'\n'],
#  [u'rt',
#   u'@carlaliones',
#   u'\u2714tweetsheet\u27a1petitions',
#   u'part',
#   u'3\u2714',
#   u'support',
#   u'the',
#   u'fight',
#   u'against',
#   u'dog&amp;cat',
#   u'meatindustry',
#   u'in',
#   u'southkorea',
#   u'http\u2026',
#   u'\n'],
#  [u'rt',
#   u'seotraversecity',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'\n'],
#  [u'rt', u'@ninelivesf', u'a', u'kitten', u'call', u'wanda', u'\n'],
#  [u'many',
#   u'of',
#   u'you',
#   u'have',
#   u'ask',
#   u'how',
#   u'wanda',
#   u'come',
#   u'to',
#   u'be',
#   u'at',
#   u'nine',
#   u'lives',
#   u'foundation',
#   u'pair',
#   u'up',
#   u'with\u2026',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'rt',
#   u'@ceektechnology',
#   u'google',
#   u'nexus6p',
#   u'review',
#   u'android',
#   u'overdose',
#   u'via',
#   u'@bgdftw',
#   u'\n'],
#  [u'rt',
#   u'@got7style',
#   u'b2gether',
#   u'got7',
#   u'with',
#   u'b',
#   u'connect',
#   u'bracelet',
#   u'\n'],
#  [u'jb', u' ', u'jackson', u' ', u'teamgot7', u'got7style', u'\n'],
#  [u'\n'],
#  [u'irulu',
#   u'tablet',
#   u'pc',
#   u'expro',
#   u'x1s',
#   u'7',
#   u'8gb/1gb',
#   u'google',
#   u'android',
#   u'4.4',
#   u'kitkat',
#   u'quad',
#   u'core',
#   u'black',
#   u'bid',
#   u'now',
#   u'\n'],
#  [u'new',
#   u'irulu',
#   u'7',
#   u'purple',
#   u'16gb',
#   u'google',
#   u'android',
#   u'4.4',
#   u'kitkat',
#   u'expro',
#   u'x1a',
#   u'hd',
#   u'tablet',
#   u'quad',
#   u'core',
#   u'bid',
#   u'now\u2026',
#   u'\n'],
#  [u'this',
#   u'house',
#   u'be',
#   u'for',
#   u'sale',
#   u'and',
#   u'what',
#   u'google',
#   u'maps',
#   u'caught',
#   u'inside',
#   u'explains',
#   u'the',
#   u'c',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'an',
#   u'apple',
#   u'a',
#   u'day',
#   u'android',
#   u'androidgames',
#   u'gameinsight',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'an',
#   u'apple',
#   u'a',
#   u'day',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'rt',
#   u'@dronelaw',
#   u'status',
#   u'report',
#   u'on',
#   u'the',
#   u'ntia',
#   u'multi',
#   u'stakeholder',
#   u'drone',
#   u'privacy',
#   u'process',
#   u'\n'],
#  [u'braided',
#   u'beard',
#   u'google',
#   u'search',
#   u'fashion',
#   u'mensfashion',
#   u'style',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'google', u'and', u'share', u'your', u'radiation', u'this', u'week', u'\n'],
#  [u'and',
#   u'tell',
#   u'your',
#   u'friend',
#   u'and',
#   u'neighbor',
#   u'your',
#   u'government',
#   u'already',
#   u'know',
#   u'\n'],
#  [u'we', u'\n'],
#  [u'g+',
#   u'somethings',
#   u'change',
#   u'as',
#   u'you',
#   u'no',
#   u'longer',
#   u'want',
#   u'to',
#   u'live',
#   u'within',
#   u'the',
#   u'same',
#   u'dusty',
#   u'hallway',
#   u' ',
#   u'thing',
#   u'be',
#   u'that',
#   u'as',
#   u'you',
#   u'clean',
#   u'up\u2026',
#   u'\n'],
#  [u'texas',
#   u'college',
#   u'student',
#   u'kill',
#   u'in',
#   u'new',
#   u'year',
#   u"'s",
#   u'eve',
#   u'shooting',
#   u'cnn',
#   u'international',
#   u'\n'],
#  [u'\n'],
#  [u'check',
#   u'out',
#   u'this',
#   u'page',
#   u'for',
#   u'the',
#   u'hot',
#   u'music',
#   u'trend',
#   u'and',
#   u'more',
#   u'search',
#   u'your',
#   u'favorite',
#   u'music',
#   u'2',
#   u'\n'],
#  [u'hey', u'check', u'out', u'these', u'2016', u'amazon', u'tip', u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'rt', u'@gopof_idiot', u'@jeanettej', u'\n'],
#  [u'none', u'but', u'bernie', u'do', u'\n'],
#  [u'\n'],
#  [u'seem',
#   u'like',
#   u'my',
#   u'bos',
#   u'be',
#   u'interested',
#   u'enough',
#   u'in',
#   u'chen',
#   u'he',
#   u'just',
#   u'google',
#   u'chen',
#   u"'s",
#   u'pic',
#   u'and',
#   u'show',
#   u'it',
#   u'to',
#   u'me',
#   u'be',
#   u'this',
#   u'chen',
#   u'he',
#   u'look',
#   u'like',
#   u'pondan',
#   u'\n'],
#  [u'rt',
#   u'@pyprecord',
#   u'look',
#   u'us',
#   u'up',
#   u'on',
#   u'itunes',
#   u'just',
#   u'google',
#   u'the',
#   u'name',
#   u'popcorn',
#   u'pyp',
#   u'or',
#   u'come',
#   u'to',
#   u'nyc',
#   u'and',
#   u'ask',
#   u'for',
#   u'me',
#   u'\n'],
#  [u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'these',
#   u'term',
#   u'no',
#   u'matter',
#   u'how',
#   u'bad',
#   u'you',
#   u'want',
#   u'to',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'yeah',
#   u'but',
#   u'its',
#   u'worth',
#   u'a',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'@darkenedsight',
#   u'taylor',
#   u"'s",
#   u'gonna',
#   u'punch',
#   u'me',
#   u'now',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'search',
#   u'how',
#   u'to',
#   u'act',
#   u'as',
#   u'if',
#   u'it',
#   u'hurt',
#   u'brb',
#   u'\U0001f607\U0001f606',
#   u'\n'],
#  [u'pluralsight',
#   u'get',
#   u'start',
#   u'with',
#   u'google',
#   u'play',
#   u'in',
#   u'app',
#   u'billing',
#   u'\n'],
#  [u'@seedchan',
#   u'ill',
#   u'send',
#   u'you',
#   u'your',
#   u'card',
#   u'from',
#   u'tw',
#   u'\n'],
#  [u'not', u'even', u'google', u'can', u'help', u'\n'],
#  [u'not',
#   u'gonna',
#   u'lie',
#   u'i',
#   u'just',
#   u'type',
#   u'what',
#   u'to',
#   u'wear',
#   u'when',
#   u'it',
#   u"'",
#   u'-15',
#   u'degree',
#   u'on',
#   u'the',
#   u'outside',
#   u'in',
#   u'google',
#   u'\n'],
#  [u'samsung',
#   u'dear',
#   u'samsung',
#   u'i',
#   u'be',
#   u'very',
#   u'annoyed',
#   u'i',
#   u'can',
#   u'not',
#   u'revert',
#   u'to',
#   u'kitkat',
#   u'from',
#   u'lollipop',
#   u'i',
#   u'have',
#   u'contact',
#   u'google',
#   u'my',
#   u'provider',
#   u'opt',
#   u'\n'],
#  [u'check', u'out', u'gosford', u'park', u'on', u'hoopladigital', u'\n'],
#  [u'british', u'mystery', u'robert', u'altman', u'great', u'aleta', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'eco',
#   u'100',
#   u'wk',
#   u'10',
#   u'quiz',
#   u'chapters',
#   u'16',
#   u'and',
#   u'17',
#   u'\n'],
#  [u'@2pmphilippine', u'pls', u'help', u'rt', u'^_^', u'\n'],
#  [u'google',
#   u"'s",
#   u'ceo',
#   u'think',
#   u'vietnam',
#   u'home',
#   u'to',
#   u'the',
#   u'next',
#   u'big',
#   u'startup',
#   u'scene',
#   u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'get', u'your', u'song', u'on', u'itunes/google', u'play', u'etc', u'\n'],
#  [u'rt',
#   u'@beautiigirl',
#   u'this',
#   u'house',
#   u'be',
#   u'for',
#   u'sale',
#   u'cheap',
#   u'when',
#   u'you',
#   u'see',
#   u'what',
#   u'google',
#   u'maps',
#   u'caught',
#   u'you',
#   u'will',
#   u'see',
#   u'why',
#   u'\n'],
#  [u'@occamsboner',
#   u'@jonathanchait',
#   u'instead',
#   u'of',
#   u'ask',
#   u'everyone',
#   u'on',
#   u'twitter',
#   u' ',
#   u'why',
#   u'do',
#   u'not',
#   u'you',
#   u'google',
#   u'it',
#   u'weirdo',
#   u'\n'],
#  [u'what',
#   u'google',
#   u'say',
#   u'about',
#   u'seo',
#   u'in',
#   u'2016',
#   u'webpronews',
#   u'\n'],
#  [u'gandalf',
#   u'=',
#   u'google',
#   u'map',
#   u'gollum',
#   u'=',
#   u'apple',
#   u'map',
#   u'\n'],
#  [u'you',
#   u"'re",
#   u'not',
#   u'go',
#   u'to',
#   u'get',
#   u'away',
#   u'with',
#   u'this',
#   u'mr.',
#   u'google',
#   u'search',
#   u'\n'],
#  [u'rt',
#   u'@stephen_mcd',
#   u'django',
#   u'1.9',
#   u'support',
#   u'just',
#   u'land',
#   u'in',
#   u'mezzanine',
#   u'please',
#   u'help',
#   u'test',
#   u'it',
#   u'django',
#   u'\n'],
#  [u'try',
#   u'tunnelbear',
#   u'for',
#   u'  ',
#   u'chrome',
#   u'  ',
#   u'to',
#   u'browse',
#   u'like',
#   u'you',
#   u"'re",
#   u'in',
#   u'another',
#   u'country',
#   u'  ',
#   u'  ',
#   u'@thetunnelbear',
#   u'  ',
#   u'\n'],
#  [u'2060',
#   u'little',
#   u'red',
#   u'schoolhouse',
#   u'slat',
#   u'open',
#   u'house',
#   u'jan.',
#   u'9',
#   u'wicked',
#   u'local',
#   u'bellingham',
#   u'\n'],
#  [u'rt',
#   u'@wearableguru',
#   u'google',
#   u'glass',
#   u'live',
#   u'see',
#   u'the',
#   u'leak',
#   u'photo',
#   u'of',
#   u'the',
#   u'next',
#   u'version',
#   u'wearabletech',
#   u'wearables',
#   u'\n'],
#  [u'the', u'papi', u'ep', u'$', u'3.99', u'on', u'google', u'play', u'\n'],
#  [u'\n'],
#  [u'whn',
#   u'ur',
#   u'fnished',
#   u'wth',
#   u'an',
#   u'essay',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'into',
#   u'google',
#   u'translate',
#   u'and',
#   u'lsten',
#   u'to',
#   u'it',
#   u'its',
#   u'the',
#   u'easy',
#   u'way',
#   u'to',
#   u'find',
#   u'mistake',
#   u'showtimetrabahula',
#   u'\n'],
#  [u'eminem', u'not', u'afraid', u'\n'],
#  [u'google',
#   u'defeats',
#   u'copyright',
#   u'lawsuit',
#   u'over',
#   u'waze',
#   u'data',
#   u'forbes',
#   u'cross',
#   u'post',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'try',
#   u'to',
#   u'google',
#   u'oh',
#   u'yeah',
#   u'eat',
#   u'that',
#   u'bible',
#   u'for',
#   u'whatever',
#   u'reason',
#   u'without',
#   u'die',
#   u'\n'],
#  [u'technique',
#   u'of',
#   u'teach',
#   u'arabic',
#   u' ',
#   u'as',
#   u'a',
#   u'foreign',
#   u'language',
#   u'through',
#   u'constructivist',
#   u'paradigm',
#   u'malaysian',
#   u'perspective',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'rt', u'@gopof_idiot', u'@libertea2012', u'\n'],
#  [u'let',
#   u'help',
#   u'bernie',
#   u'get',
#   u'his',
#   u'message',
#   u'out',
#   u'since',
#   u'the',
#   u'medium',
#   u'be',
#   u'not',
#   u'help',
#   u'him',
#   u'like',
#   u'they',
#   u'r',
#   u'hillary',
#   u'&amp',
#   u'trump',
#   u'https:\u2026',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'now',
#   u'an',
#   u'e',
#   u'list',
#   u'celebrity',
#   u'in',
#   u'kim',
#   u'kardashian',
#   u'hollywood',
#   u'you',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'android',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'native',
#   u'american',
#   u'flute',
#   u'music',
#   u'meditation',
#   u'music',
#   u'for',
#   u'shamanic',
#   u'astral',
#   u'projection',
#   u'healing',
#   u'music',
#   u'\n'],
#  [u'rt',
#   u'@ezralevant',
#   u'here',
#   u"'",
#   u'why',
#   u'i',
#   u'be',
#   u'worried',
#   u'about',
#   u'censorship',
#   u'from',
#   u'@google',
#   u'@twitter',
#   u'&amp',
#   u'@facebook',
#   u'in',
#   u'2016',
#   u'because',
#   u'they',
#   u'say',
#   u'they',
#   u'will',
#   u'do',
#   u'it',
#   u'https:/\u2026',
#   u'\n'],
#  [u'course',
#   u'material',
#   u'for',
#   u'statistics',
#   u'the',
#   u'easier',
#   u'way',
#   u'with',
#   u'r',
#   u'rstats',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'3',
#   u'big',
#   u'lessons',
#   u'from',
#   u'3',
#   u'successful',
#   u'entrepreneurs',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'google', u'puckle', u'gun', u'\n'],
#  [u'hip',
#   u'hop',
#   u'alumni',
#   u'hha',
#   u'@google',
#   u'blogger',
#   u'&amp',
#   u'hha',
#   u'@youtube',
#   u'channel',
#   u'2016',
#   u'\n'],
#  [u'@rustybrick',
#   u'sir',
#   u'please',
#   u'tell',
#   u'me',
#   u'late',
#   u'@google',
#   u'algorithm',
#   u'in',
#   u'2016',
#   u'\n'],
#  [u'@kappa_kappa',
#   u'you',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'for',
#   u'real',
#   u'\n'],
#  [u'2057',
#   u'paul',
#   u'jacoulet',
#   u"'s",
#   u'widowed',
#   u'mother',
#   u'remarry',
#   u'and',
#   u'settle',
#   u'in',
#   u'korea',
#   u'his',
#   u'maine',
#   u'antique',
#   u'digest',
#   u'\n'],
#  [u'rt',
#   u'@abogomolov',
#   u'new',
#   u'in',
#   u'symfony',
#   u'2.8',
#   u'dx',
#   u'improvements',
#   u'\n'],
#  [u'\n'],
#  [u'symfony', u'\n'],
#  [u'@georgina944',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'phase',
#   u'one',
#   u'xf',
#   u'100mp',
#   u'use',
#   u'similar',
#   u'a7rii',
#   u'sensor',
#   u'tech',
#   u'first',
#   u'short',
#   u'image',
#   u'test',
#   u'impression',
#   u'|\u2026',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'eminem', u'the', u'real', u'slim', u'shady', u'edited', u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'rt',
#   u'@realgoai',
#   u'when',
#   u'you',
#   u'google',
#   u'one',
#   u'question',
#   u'and',
#   u'find',
#   u'a',
#   u'quizlet',
#   u'for',
#   u'the',
#   u'whole',
#   u'test',
#   u'\n'],
#  [u'rt',
#   u'@teropa',
#   u'google',
#   u'analytics',
#   u'tell',
#   u'me',
#   u'the',
#   u'full',
#   u'stack',
#   u'redux',
#   u'tutorial',
#   u'have',
#   u'pass',
#   u'110k',
#   u'visitor',
#   u'that',
#   u'\u2019s',
#   u'crazy',
#   u'\n'],
#  [u'rt', u'@mikealbers23', u'great', u'new', u'workout', u'app', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'workout', u'fitness', u'gym', u'exercise', u'health', u'\n'],
#  [u'downtonabbey', u'quickworkout', u'http\u2026', u'\n'],
#  [u'@lawwrah',
#   u'@kla_anne33',
#   u'@itsothquote',
#   u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'it',
#   u'i',
#   u'always',
#   u'make',
#   u'that',
#   u'mistake',
#   u'still',
#   u'so',
#   u'good',
#   u'though',
#   u'\u2764\ufe0f',
#   u'\n'],
#  [u'@aizanzenzon',
#   u'go',
#   u'google',
#   u'about',
#   u'it',
#   u'and',
#   u'whatsapp',
#   u'me',
#   u'we',
#   u'can',
#   u'always',
#   u'plan',
#   u'\U0001f609',
#   u'\n'],
#  [u'iphone',
#   u'and',
#   u'ipad',
#   u'price',
#   u'go',
#   u'up',
#   u'in',
#   u'germany',
#   u'due',
#   u'to',
#   u'country',
#   u"'s",
#   u'private',
#   u'copying',
#   u'fee',
#   u'\n'],
#  [u'wedding',
#   u'gown',
#   u'survive',
#   u'tornado',
#   u'illinois',
#   u'farmer',
#   u'help',
#   u'reunite',
#   u'bride',
#   u'with',
#   u'ktrk',
#   u'tv',
#   u'\n'],
#  [u'@gauravpandhi',
#   u'@zubinaahmad',
#   u'@samarg_uvaach',
#   u'@reviewero',
#   u'if',
#   u'u',
#   u'want',
#   u'to',
#   u'play',
#   u'dirty',
#   u'politics',
#   u'then',
#   u'their',
#   u'r',
#   u'enough',
#   u'to',
#   u'be',
#   u'find',
#   u'on',
#   u'google',
#   u'against',
#   u'bjp',
#   u'\n'],
#  [u'fuse',
#   u'location',
#   u'provider',
#   u'in',
#   u'google',
#   u'play',
#   u'services8.4',
#   u'provide',
#   u'location',
#   u'to',
#   u'an',
#   u'app.https://t.co/mrvkmesqgd',
#   u'\n'],
#  [u'developer', u'\n'],
#  [u'turn',
#   u'your',
#   u'phone',
#   u'into',
#   u'a',
#   u'lightsaber',
#   u'with',
#   u'this',
#   u'mind',
#   u'blow',
#   u'google',
#   u'chrome',
#   u'experiment',
#   u'starwars',
#   u'\n'],
#  [u'@hollyheatbeat',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'twitpane', u'  ', u'\n'],
#  [u'from',
#   u'digital',
#   u'disappointment',
#   u'tothe',
#   u'end',
#   u'of',
#   u'the',
#   u'app',
#   u'era',
#   u'here',
#   u'be',
#   u'eight',
#   u'trends',
#   u'for',
#   u'\n'],
#  [u'rt', u'@senyora', u'dam', u'handa', u'ah', u'google', u'\n'],
#  [u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'themeforest',
#   u'be',
#   u'awesome',
#   u'for',
#   u'buy',
#   u'custom',
#   u'templates',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'rt',
#   u'@artfulkis',
#   u'i',
#   u'google',
#   u'earthed',
#   u'my',
#   u'house',
#   u'and',
#   u'i',
#   u'saw',
#   u'something',
#   u'in',
#   u'my',
#   u'window',
#   u'and',
#   u'its',
#   u'louis',
#   u'cardboard',
#   u'cut',
#   u'out',
#   u'\n'],
#  [u'@ckirubi', u'hello', u'sir', u'watch', u'my', u'new', u'video', u'\n'],
#  [u'rt', u'@realshigerum', u'don\u2019t', u'google', u'sexy', u'yoshi', u'\n'],
#  [u'rt',
#   u'fashion',
#   u'apparel',
#   u'and',
#   u'retail',
#   u'stock',
#   u'end',
#   u'2015',
#   u'with',
#   u'whimper',
#   u'wwd',
#   u'\n'],
#  [u'\n'],
#  [u'fashion', u'apparel', u'and', u'ret\u2026', u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'famina',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'impact',
#   u'socbiz',
#   u'biz',
#   u'\n'],
#  [u'@lee_yooyoung_', u'translate', u'to', u'google', u'then', u':"c', u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@jasondemanzo',
#   u'with',
#   u'as',
#   u'much',
#   u'as',
#   u'they',
#   u'pay',
#   u'in',
#   u'luxury',
#   u'tax',
#   u'&amp',
#   u'rev',
#   u'from',
#   u'the',
#   u'new',
#   u'cable',
#   u'deal',
#   u'kobe',
#   u'deal',
#   u'be',
#   u'not',
#   u'a',
#   u'problem',
#   u'you',
#   u'go',
#   u'google',
#   u'something',
#   u'moron',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'google',
#   u'\u2019s',
#   u'schmidt',
#   u'say',
#   u'this',
#   u'nation',
#   u'lead',
#   u'e',
#   u'commerce',
#   u'news',
#   u'market',
#   u'business',
#   u'\n'],
#  [u'the',
#   u'nexus',
#   u'reload',
#   u'google',
#   u'nexus',
#   u'5x',
#   u'&amp',
#   u'6p',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'how',
#   u'to',
#   u'overcome',
#   u'isolation',
#   u'while',
#   u'you',
#   u'make',
#   u'money',
#   u'online',
#   u' ',
#   u'easy',
#   u'money',
#   u'\n'],
#  [u'fire', u'event', u'e017', u'runnels', u'east', u'dr', u'23:29', u'\n'],
#  [u'automatic',
#   u'alarm',
#   u'e011',
#   u'birdsall',
#   u'st',
#   u'washington',
#   u'ave',
#   u'23:27',
#   u'\n'],
#  [u'@andrearene',
#   u'@johntdrake',
#   u'i',
#   u'honestly',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'watch',
#   u'captain',
#   u'ron',
#   u'instead',
#   u'\n'],
#  [u'surprising',
#   u'amount',
#   u'of',
#   u'result',
#   u'on',
#   u'google',
#   u'search',
#   u'for',
#   u'alien',
#   u'with',
#   u'a',
#   u'comb',
#   u'over',
#   u'say',
#   u'it',
#   u'all',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@koolkaattt_',
#   u'what',
#   u'about',
#   u'your',
#   u'google',
#   u'docs?\U0001f602',
#   u'\n'],
#  [u'rt',
#   u'@kappa_kappa',
#   u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'c\u2026',
#   u'\n'],
#  [u'fiverrworks',
#   u'use',
#   u'this',
#   u'service',
#   u'to',
#   u'make',
#   u'lot',
#   u'of',
#   u'money',
#   u'by',
#   u'google',
#   u'read',
#   u'more',
#   u'fiverr',
#   u'se\u2026',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'ringleader', u'by', u'public', u'memory', u'nowplaying', u'beats1', u'\n'],
#  [u'try',
#   u'subscriber',
#   u'for',
#   u'youtube',
#   u' ',
#   u'get',
#   u'1000+',
#   u'real',
#   u'subscriber',
#   u'for',
#   u'your',
#   u'youtube',
#   u'channel',
#   u'google',
#   u'play:https://t.co/dxiw10zydv',
#   u'\n'],
#  [u'fiverrsociall',
#   u'use',
#   u'this',
#   u'service',
#   u'to',
#   u'make',
#   u'lot',
#   u'of',
#   u'money',
#   u'by',
#   u'google',
#   u'read',
#   u'more',
#   u'fiverr',
#   u'\n'],
#  [u'trendy', u'and', u'fashionable', u'\n'],
#  [u'rt',
#   u'@movylent',
#   u'\U0001f506',
#   u'best',
#   u'of',
#   u'2015',
#   u'how',
#   u'valve',
#   u"'s",
#   u'pay',
#   u'mod',
#   u'program',
#   u'implode',
#   u'in',
#   u'four',
#   u'day',
#   u'androidgames',
#   u'\n'],
#  [u'more', u'at', u'\n'],
#  [u'traffic',
#   u'stop',
#   u'at',
#   u's',
#   u'bell',
#   u'ave',
#   u'&amp',
#   u'e',
#   u'7th',
#   u'st',
#   u'shawnee',
#   u'\n'],
#  [u'eco',
#   u'100',
#   u'wk',
#   u'11',
#   u'final',
#   u'exam',
#   u'part',
#   u'i',
#   u'&amp',
#   u'ii',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'tiny',
#   u'village',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'go', u'analysis', u'use', u'clusterprofiler', u'rstats', u'\n'],
#  [u'the',
#   u'device',
#   u'apps',
#   u'and',
#   u'accessory',
#   u'i',
#   u'use',
#   u'most',
#   u'in',
#   u'2015',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'@vivieennne',
#   u'its',
#   u'always',
#   u'tough',
#   u'get',
#   u'diagnose',
#   u'by',
#   u'google',
#   u'and',
#   u'greys',
#   u'we',
#   u'be',
#   u'here',
#   u'for',
#   u'you',
#   u'\n'],
#  [u'what',
#   u"'",
#   u'the',
#   u'best',
#   u'place',
#   u'to',
#   u'hide',
#   u'evidence',
#   u'page',
#   u'2',
#   u'of',
#   u'google',
#   u'nobody',
#   u'will',
#   u'look',
#   u'there',
#   u'seo',
#   u'joke',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'you',
#   u'should',
#   u'consider',
#   u'deep',
#   u'link',
#   u'to',
#   u'build',
#   u'authority',
#   u' ',
#   u'make',
#   u'fast',
#   u'cash',
#   u'\n'],
#  [u'rt', u'@harry_style', u'1d', u'day', u'innit', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@joshgrigorean',
#   u'google',
#   u'the',
#   u'definition',
#   u'of',
#   u'terrorism',
#   u'\n'],
#  [u'tip',
#   u'pass',
#   u'process',
#   u'in',
#   u'order',
#   u'to',
#   u'issue',
#   u'diagonal',
#   u'as',
#   u'much',
#   u'as',
#   u'it',
#   u'wantage',
#   u'plus',
#   u'google',
#   u'lmacrfzq',
#   u'\n'],
#  [u'so',
#   u'when',
#   u'i',
#   u'get',
#   u'the',
#   u'worm',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'because',
#   u'i',
#   u'be',
#   u'like',
#   u'what',
#   u'in',
#   u'the',
#   u'fcuk',
#   u'this',
#   u'actually',
#   u'happen',
#   u'forreal',
#   u'i',
#   u'think',
#   u'just',
#   u'some',
#   u'movieish',
#   u'\n'],
#  [u'i',
#   u'type',
#   u'fat',
#   u'domino',
#   u'behind',
#   u'the',
#   u'scenes',
#   u'into',
#   u'that',
#   u'there',
#   u'google',
#   u'and',
#   u'saw',
#   u'myself',
#   u' ',
#   u'umm',
#   u'ok',
#   u'\U0001f633\U0001f914\u2026',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'you',
#   u'should',
#   u'love',
#   u'twitter',
#   u'advertising',
#   u' ',
#   u'make',
#   u'fast',
#   u'cash',
#   u'\n'],
#  [u'zspirov',
#   u'rt',
#   u'mikealbers23',
#   u'great',
#   u'new',
#   u'workout',
#   u'app',
#   u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'workout', u'fitness', u'gym', u'exercise', u'health', u'\n'],
#  [u'downtonabbey', u'quickwor\u2026', u'\n'],
#  [u'new',
#   u'psa',
#   u'urge',
#   u'action',
#   u'on',
#   u'grow',
#   u'medical',
#   u'marijuana',
#   u'in',
#   u'state',
#   u'wxia',
#   u'tv',
#   u'potbot',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'the',
#   u'federal',
#   u'ban',
#   u'on',
#   u'medical',
#   u'marijuana',
#   u'be',
#   u'not',
#   u'lift',
#   u'reason',
#   u'blog',
#   u'potbot',
#   u'\n'],
#  [u'rt',
#   u'@chrisbrown',
#   u'download',
#   u'royalty',
#   u'on',
#   u'google',
#   u'play',
#   u'today',
#   u'\n'],
#  [u'physician',
#   u'want',
#   u'robust',
#   u'study',
#   u'on',
#   u'medical',
#   u'marijuana',
#   u'use',
#   u'pittsburgh',
#   u'post',
#   u'gazette',
#   u'potbot',
#   u'\n'],
#  [u'before',
#   u'go',
#   u'to',
#   u'the',
#   u'gym',
#   u'google',
#   u'arnold',
#   u'schwarzenegger',
#   u'shirtless',
#   u'recent',
#   u'click',
#   u'image',
#   u'and',
#   u'stay',
#   u'home',
#   u'instead',
#   u'\n'],
#  [u'rt',
#   u'@alingtutan',
#   u'whn',
#   u'ur',
#   u'fnished',
#   u'wth',
#   u'an',
#   u'essay',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'into',
#   u'google',
#   u'translate',
#   u'and',
#   u'lsten',
#   u'to',
#   u'it',
#   u'its',
#   u'the',
#   u'easy',
#   u'way',
#   u'to',
#   u'find',
#   u'mistake',
#   u's\u2026',
#   u'\n'],
#  [u'virat',
#   u'kohli',
#   u'congratulate',
#   u'indian',
#   u'football',
#   u'team',
#   u'for',
#   u'beat',
#   u'afghanistan',
#   u'in',
#   u'saff',
#   u'daily',
#   u'news',
#   u'&amp',
#   u'analysis',
#   u'|',
#   u'\n'],
#  [u'get',
#   u'screen',
#   u'grab',
#   u'if',
#   u'it',
#   u'happen',
#   u' ',
#   u'google',
#   u'how',
#   u'to',
#   u'do',
#   u'assertion',
#   u'unsupported',
#   u'by',
#   u'fact',
#   u'do',
#   u'not',
#   u'help',
#   u'ur',
#   u'advocacy',
#   u'sot',
#   u'\U0001f1fa\U0001f1f8',
#   u'\n'],
#  [u'math', u'labyrinth', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'@tentardi',
#   u'can',
#   u'not',
#   u'search',
#   u'for',
#   u'it',
#   u'bc',
#   u'i',
#   u'do',
#   u'not',
#   u'have',
#   u'enough',
#   u'data',
#   u'plan',
#   u'for',
#   u'google',
#   u'in',
#   u'safari',
#   u'rn',
#   u'rip',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@yoboykaleb',
#   u'@nlgabe_',
#   u'lucked',
#   u'out',
#   u'with',
#   u'with',
#   u'find',
#   u'it',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'accident', u'254', u'peachtree', u'st', u'sw', u'@city', u'jail', u'\n'],
#  [u'rt',
# ...
#   u'deal',
#   u'\n'],
#  [u'the',
#   u'diary',
#   u'of',
#   u'a',
#   u'young',
#   u'girl',
#   u'anne',
#   u'frank',
#   u'now',
#   u'trend',
#   u'on',
#   u'google',
#   u'philippine',
#   u'search',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'go',
#   u'giant',
#   u'check',
#   u'late',
#   u'ny',
#   u'giant',
#   u'update',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'@h3bk11',
#   u'what',
#   u'it',
#   u'\u2019',
#   u'really',
#   u'like',
#   u'to',
#   u'work',
#   u'for',
#   u'a',
#   u'tech',
#   u'giant',
#   u'be',
#   u'sanfrancisco',
#   u'in',
#   u'siliconvalley?the',
#   u'answer',
#   u'be',
#   u'yes',
#   u' ',
#   u'\n'],
#  [u'what',
#   u'motivate',
#   u'us',
#   u'to',
#   u'want',
#   u'unusual',
#   u'pet',
#   u'news',
#   u'kamloops',
#   u'blog',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'mominul199',
#   u'sam___hurley',
#   u'google',
#   u'penalty',
#   u'recovery',
#   u'guide',
#   u'for',
#   u'execs',
#   u'free',
#   u'ebook',
#   u'guide',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'if', u'u', u'need', u'this', u'the', u'fbeye', u'lol', u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'rt',
#   u'@jackgilinsky',
#   u'i',
#   u'be',
#   u'lay',
#   u'naked',
#   u'outside',
#   u'&amp',
#   u'i',
#   u'just',
#   u'think',
#   u'to',
#   u'myself',
#   u'what',
#   u'if',
#   u'google',
#   u'map',
#   u'be',
#   u'take',
#   u'their',
#   u'annual',
#   u'satellite',
#   u'picture',
#   u'right',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'buy',
#   u'usa',
#   u'instagram',
#   u'follower',
#   u'buy',
#   u'website',
#   u'traffic',
#   u'with',
#   u'verify',
#   u'google',
#   u'analytics',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'the', u'sun', u'on', u'4', u'january', u'2016', u'sun', u' ', u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'today',
#   u'google',
#   u'suggest',
#   u'i',
#   u'search',
#   u'for',
#   u'image',
#   u'of',
#   u'\n'],
#  [u'@katyperry',
#   u"'s",
#   u'twin',
#   u'@carlythekatycat',
#   u'be',
#   u'all',
#   u'that',
#   u'come',
#   u'up',
#   u'\n'],
#  [u'@pdhana',
#   u'@bkdoss',
#   u'@psrajarajan',
#   u'@plk_raja',
#   u'google',
#   u'itself',
#   u'be',
#   u'make',
#   u'comedy',
#   u'ev',
#   u'ramasamy',
#   u'naaickar',
#   u'\U0001f61b\U0001f61c\U0001f600',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'@wedodumbthing',
#   u'@thenamesyousef',
#   u'@acaiabrese',
#   u'i',
#   u'try',
#   u'just',
#   u'google',
#   u'the',
#   u'one',
#   u'that',
#   u'be',
#   u'not',
#   u'filler',
#   u'it',
#   u'just',
#   u'be',
#   u'not',
#   u'for',
#   u'me',
#   u'i',
#   u'get',
#   u'to',
#   u'ep',
#   u'200',
#   u'lol',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'rt',
#   u'@paperphotoyo',
#   u'just',
#   u'have',
#   u'to',
#   u'google',
#   u'synonyms',
#   u'for',
#   u'the',
#   u'word',
#   u'creative',
#   u'\n'],
#  [u'\n'],
#  [u'the', u'irony', u'be', u'not', u'lose', u'on', u'me', u'\n'],
#  [u'rt',
#   u'@arzaylea',
#   u'@sweetiieslrh',
#   u'google',
#   u'instagram',
#   u'bio',
#   u'space',
#   u'and',
#   u'it',
#   u'will',
#   u'let',
#   u'you',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'\n'],
#  [u'bracket',
#   u'update',
#   u'changed',
#   u'sizing',
#   u'to',
#   u'make',
#   u'reading',
#   u'easy',
#   u'\n'],
#  [u'@mariahjordan9',
#   u'at',
#   u'least',
#   u'google',
#   u'be',
#   u'try',
#   u'to',
#   u'say',
#   u'a',
#   u'life',
#   u'\n'],
#  [u'what',
#   u'self',
#   u'fix',
#   u'negativity.1',
#   u'occur',
#   u'google',
#   u'present',
#   u'time',
#   u'40',
#   u'day',
#   u'my',
#   u'recondite',
#   u'automation',
#   u'lickspit',
#   u'opmg',
#   u'\n'],
#  [u'google', u'cultural', u'institute', u'\n'],
#  [u'create',
#   u'your',
#   u'own',
#   u'gallery',
#   u'and',
#   u'share',
#   u'favourite',
#   u'find',
#   u'with',
#   u'friend',
#   u'\n'],
#  [u'\n'],
#  [u'i',
#   u'be',
#   u'now',
#   u'a',
#   u'd',
#   u'list',
#   u'celebrity',
#   u'in',
#   u'kim',
#   u'kardashian',
#   u'hollywood',
#   u'you',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'android',
#   u'\n'],
#  [u'love',
#   u'this',
#   u'check',
#   u'out',
#   u'all',
#   u'for',
#   u'one',
#   u'by',
#   u'five',
#   u'for',
#   u'fight',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@nadimah1505', u'here', u'you', u'go', u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https:\u2026',
#   u'\n'],
#  [u'if',
#   u'interest',
#   u'in',
#   u'help',
#   u'test',
#   u'mazevr',
#   u'for',
#   u'google',
#   u'cardboard',
#   u'on',
#   u'iphone',
#   u'5',
#   u'or',
#   u'6',
#   u'dm',
#   u'your',
#   u'email',
#   u'address',
#   u'testflight',
#   u'require',
#   u'it',
#   u'thanks',
#   u'\n'],
#  [u'broker',
#   u'the',
#   u'premium',
#   u'domain',
#   u'interested',
#   u'@aol',
#   u'@comcast',
#   u'@google',
#   u'@yahoo',
#   u'@b',
#   u'@msn',
#   u'@microsoft',
#   u'\n'],
#  [u'rt',
#   u'@im__joshi',
#   u'@pdhana',
#   u'@bkdos',
#   u'@psrajarajan',
#   u'@plk_raja',
#   u'google',
#   u'itself',
#   u'be',
#   u'make',
#   u'comedy',
#   u'ev',
#   u'ramasamy',
#   u'naaickar',
#   u'\U0001f61b\U0001f61c\U0001f600',
#   u'\n'],
#  [u'i',
#   u'like',
#   u'a',
#   u'@youtube',
#   u'video',
#   u'10',
#   u'thing',
#   u'you',
#   u'should',
#   u'never',
#   u'google',
#   u'warning',
#   u'gross',
#   u'\n'],
#  [u'rt',
#   u'@eastridgeibl',
#   u'week',
#   u'2',
#   u'power',
#   u'rankings\U0001f608',
#   u'\n'],
#  [u'sometimes',
#   u'i',
#   u'google',
#   u'cute',
#   u'way',
#   u'to',
#   u'ask',
#   u'someone',
#   u'out',
#   u'cause',
#   u'my',
#   u'idea',
#   u'suck',
#   u'asf',
#   u'\n'],
#  [u'sb',
#   u'nation',
#   u'colt',
#   u'vs.',
#   u'titans',
#   u'final',
#   u'score',
#   u'colts',
#   u'beat',
#   u'titans',
#   u'30',
#   u'24',
#   u'in',
#   u'what',
#   u'be',
#   u'likely',
#   u'chuck',
#   u'pagano',
#   u"'s",
#   u'final',
#   u'game',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'rt', u'@lovelife201114', u'makingamurderer', u'@helpstevenavery', u'\n'],
#  [u'\n'],
#  [u'one',
#   u'can',
#   u'leave',
#   u'the',
#   u'sherifs',
#   u'office',
#   u'comment',
#   u'via',
#   u'google',
#   u'map',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'not',
#   u'sure',
#   u'what',
#   u'you',
#   u'mean',
#   u'what',
#   u'sort',
#   u'of',
#   u'question',
#   u'i',
#   u'like',
#   u'stikman',
#   u'google',
#   u'him',
#   u'if',
#   u'you',
#   u'have',
#   u'question',
#   u'know',
#   u'a',
#   u'ton',
#   u'\n'],
#  [u'google', u'answer', u'your', u'question', u'\n'],
#  [u'larrypage', u'answer', u'the', u'fundamental', u'question', u'\n'],
#  [u'mondaymotivation', u'quote', u'\n'],
#  [u'agoa',
#   u'trade',
#   u'stand',
#   u'off',
#   u'tie',
#   u'between',
#   u'sa',
#   u'us',
#   u'in',
#   u'jeopardy',
#   u'|',
#   u'enca',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@jasondemanzo',
#   u'it',
#   u'will',
#   u'give',
#   u'you',
#   u'something',
#   u'to',
#   u'google',
#   u'since',
#   u'you',
#   u'think',
#   u'you',
#   u'know',
#   u'so',
#   u'much',
#   u'\n'],
#  [u'try',
#   u'to',
#   u'find',
#   u'bootleg',
#   u'version',
#   u'of',
#   u'tfa',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'the',
#   u'best',
#   u'advice',
#   u'i',
#   u'have',
#   u'ever',
#   u'receive',
#   u'from',
#   u'google',
#   u'how',
#   u'to',
#   u'numb',
#   u'emotional',
#   u'pain',
#   u'\n'],
#  [u'thanks',
#   u'for',
#   u'follow',
#   u'@egibis_blog',
#   u'look',
#   u'for',
#   u'me',
#   u'on',
#   u'fb',
#   u'google+',
#   u'linkedin',
#   u'&amp',
#   u'pinterest',
#   u'under',
#   u'trucrowd',
#   u'see',
#   u'ya',
#   u'there',
#   u'\n'],
#  [u'eco', u'302', u'week', u'3', u'quiz', u'strayer-', u'\n'],
#  [u'7',
#   u'a33',
#   u'google',
#   u'android',
#   u'4.4',
#   u'quad',
#   u'core',
#   u'dual',
#   u'camera',
#   u'8gb',
#   u'tablet',
#   u'pc',
#   u'wifi',
#   u'bluetooth',
#   u'bid',
#   u'now',
#   u'on\u2026',
#   u'\n'],
#  [u'google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panel',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panel',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'@wisdom_star',
#   u'summary',
#   u'of',
#   u'the',
#   u'rise',
#   u'of',
#   u'hate',
#   u'search',
#   u'wisdomstarsnews',
#   u'hatecrimes',
#   u'google',
#   u'terrorism',
#   u'parisattacks',
#   u'\n'],
#  [u'reliable',
#   u'seattle',
#   u'town',
#   u'car',
#   u'hire',
#   u'service',
#   u'.for',
#   u'more',
#   u'information',
#   u'click',
#   u'on',
#   u'this',
#   u'link',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'listen',
#   u'to',
#   u'something',
#   u'you',
#   u'forgot',
#   u'carter',
#   u'3',
#   u'by',
#   u'lil',
#   u'wanye',
#   u'|',
#   u'\n'],
#  [u'rt',
#   u'@dave_ri',
#   u'top',
#   u'10',
#   u'google',
#   u'docs',
#   u'posts',
#   u'of',
#   u'2015',
#   u'via',
#   u'@alicekeeler',
#   u'edtech',
#   u'\n'],
#  [u'@poptivist',
#   u'@buttercupcas',
#   u'here',
#   u'you',
#   u'go',
#   u'i',
#   u'hope',
#   u'it',
#   u'works',
#   u'\n'],
#  [u'google', u' ', u'\n'],
#  [u'the',
#   u'associated',
#   u'press',
#   u'steelers',
#   u'sneak',
#   u'into',
#   u'afc',
#   u'playoff',
#   u'with',
#   u'28',
#   u'12',
#   u'win',
#   u'over',
#   u'browns',
#   u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https:\u2026',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'saw',
#   u'this..thank',
#   u'you',
#   u'for',
#   u'share',
#   u'it',
#   u'\n'],
#  [u'waka',
#   u'flocka',
#   u'&amp',
#   u'young',
#   u'sizzle',
#   u'new',
#   u'year',
#   u'prod',
#   u'by',
#   u'luke',
#   u'\n'],
#  [u'@jeremylawrencee',
#   u'ya',
#   u'fios',
#   u'here',
#   u'at',
#   u'my',
#   u'place',
#   u'and',
#   u'at',
#   u'my',
#   u'parent',
#   u'hopefully',
#   u'we',
#   u'get',
#   u'google',
#   u'fiber',
#   u'here',
#   u'\n'],
#  [u'spyhuman',
#   u'be',
#   u'mobile',
#   u'track',
#   u'application',
#   u'gp',
#   u' ',
#   u'call',
#   u'log',
#   u'call',
#   u'record',
#   u'\n'],
#  [u'\n'],
#  [u'so',
#   u'thankful',
#   u'for',
#   u'the',
#   u'google',
#   u'chromecast',
#   u'let',
#   u'me',
#   u'stream',
#   u'music',
#   u'from',
#   u'my',
#   u'phone',
#   u'to',
#   u'my',
#   u'tv\U0001f64f\U0001f64f\U0001f64f\U0001f64f',
#   u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'google',
#   u'support',
#   u'swedish',
#   u'chef',
#   u'from',
#   u'the',
#   u'muppets',
#   u'@muppetsstudio',
#   u'internet',
#   u'technology',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'how', u'to', u'use', u'google', u'effectively', u'\n'],
#  [u'rt',
#   u'@wmsolomon',
#   u'do',
#   u'not',
#   u'use',
#   u'google',
#   u'for',
#   u'your',
#   u'research',
#   u'just',
#   u'read',
#   u'history',
#   u'it',
#   u"'",
#   u'fun',
#   u'educate',
#   u'&amp',
#   u'relevant',
#   u'in',
#   u'a',
#   u'funny',
#   u'way',
#   u'history',
#   u'keep',
#   u'repeatin\u2026',
#   u'\n'],
#  [u'socialmediatips',
#   u'powerful',
#   u'personal',
#   u'branding',
#   u'tips',
#   u'to',
#   u'take',
#   u'you',
#   u'from',
#   u'digital',
#   u'zero',
#   u'+smm\u21achttps://t.co/2doa1wscru',
#   u'\n'],
#  [u'socialmediatips',
#   u'powerful',
#   u'personal',
#   u'branding',
#   u'tips',
#   u'to',
#   u'take',
#   u'you',
#   u'from',
#   u'digital',
#   u'zero',
#   u'+smm\u21achttps://t.co/vnedwwkkhb',
#   u'\n'],
#  [u'sometimes',
#   u'i',
#   u'call',
#   u'303',
#   u'499',
#   u'7111',
#   u'and',
#   u'listen',
#   u'to',
#   u'the',
#   u'atomic',
#   u'clock',
#   u'at',
#   u'nist',
#   u'tick',
#   u'off',
#   u'second',
#   u'at',
#   u'the',
#   u'tone',
#   u'5:44',
#   u'utc',
#   u'\n'],
#  [u'microsoft',
#   u'will',
#   u'inform',
#   u'you',
#   u'if',
#   u'government',
#   u'be',
#   u'spy',
#   u'on',
#   u'you',
#   u'\n'],
#  [u'@mesipisu', u'new', u'video', u'alert', u'\n'],
#  [u'rt',
#   u'@surajravifan',
#   u'miruthantrailer',
#   u'rock',
#   u'@youtube',
#   u'with',
#   u'6',
#   u'lakhs+',
#   u'view',
#   u'&amp',
#   u'8k+',
#   u'likes',
#   u'@actor_jayamravi',
#   u'@shaktirajan',
#   u'therihit',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'zaker',
#   u'pro',
#   u'azkar',
#   u'muslim',
#   u'pray',
#   u'android',
#   u'apps',
#   u'on',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'write',
#   u'an',
#   u'android',
#   u'application',
#   u' ',
#   u'by',
#   u'patilvaibhavp99',
#   u'i',
#   u'want',
#   u'to',
#   u'integrate',
#   u'google',
#   u'auto',
#   u'complete',
#   u'place',
#   u' ',
#   u'api',
#   u'in',
#   u'android',
#   u'ap\u2026',
#   u'\n'],
#  [u'.@sardesairajdeep',
#   u'it',
#   u'take',
#   u'58',
#   u'minute',
#   u'now',
#   u'as',
#   u'per',
#   u'google',
#   u'map',
#   u'unless',
#   u'of',
#   u'course',
#   u'google',
#   u'be',
#   u'a',
#   u'modi',
#   u'agent',
#   u'\n'],
#  [u'universo',
#   u'nokia',
#   u'newsspot',
#   u'google',
#   u'reader',
#   u'potente',
#   u'e',
#   u'versatile',
#   u'\n'],
#  [u'rt',
#   u'@koderedapp',
#   u'check',
#   u'out',
#   u'our',
#   u'new',
#   u'android',
#   u'game',
#   u'roadrage',
#   u'endless',
#   u'free',
#   u'addictive',
#   u'shooter',
#   u'racing',
#   u'rocket',
#   u'b\u2026',
#   u'\n'],
#  [u'rt',
#   u'@bella230893',
#   u'preview',
#   u'bestplan',
#   u'calendar',
#   u'by',
#   u'@planbap',
#   u'\n'],
#  [u'to',
#   u'order',
#   u'please',
#   u'refer',
#   u'here',
#   u'\U0001f447\U0001f3fb(malaysia',
#   u'go',
#   u'\n'],
#  [u'1451886241-weekly',
#   u'european',
#   u'tour',
#   u'fantasy',
#   u'golf',
#   u'app',
#   u'for',
#   u'android',
#   u'\n'],
#  [u'the',
#   u'associated',
#   u'press',
#   u'viking',
#   u'take',
#   u'nfc',
#   u'north',
#   u'hold',
#   u'on',
#   u'to',
#   u'beat',
#   u'packer',
#   u'20',
#   u'13',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@emmaajoyce',
#   u'@chichenry',
#   u'i',
#   u'look',
#   u'it',
#   u'up',
#   u'on',
#   u'google',
#   u'and',
#   u'it',
#   u'give',
#   u'me',
#   u'nothing',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'legendary',
#   u'island',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  ...]

# %%
sentence

# %% [markdown]
# ## Exercise 1a
#
# Write a function that can take a take a sentence parsed by `spacy` and identify if it mentions a company named 'Google'. Remember, `spacy` can find entities and codes them as `ORG` if they are a company. Look at the slides for class 13 if you need a hint:
#
# ### Bonus (1b)
#
# Parameterize the company name so that the function works for any company.

# %%
def mentions_company(parsed):
    # Return True if the sentence contains an organization and that organization is Google
#     for entity in parsed.ents:
#     # Fill in code here
#     # Otherwise return False
#     return False


# 1b

def mentions_company(parsed, company='Google'):
    # Your code here
    print "parsed=", parsed
    print "company=", company
    pass

# %%
tweets[:10]

transformed_tweets = [[token.lemma_ for token in english_parser(t) if not token.is_punct and not token.like_url] for t in tweets]

transformed_tweets
# Out:
# [[u'i',
#   u'make',
#   u'a(n',
#   u'small',
#   u'tourmaline',
#   u'in',
#   u'paradise',
#   u'island',
#   u'gameinsight',
#   u'androidgames',
#   u'android',
#   u'\n'],
#  [u'rt',
#   u'@purelovebeast',
#   u'-\u0e40\u0e0a\u0e47\u0e04\u0e23\u0e32\u0e22\u0e25\u0e30\u0e40\u0e2d\u0e35\u0e22\u0e14-',
#   u'27th',
#   u'birthday',
#   u'special',
#   u'goods',
#   u'3d',
#   u'yoseop',
#   u'usb',
#   u'\n'],
#  [u'\n'],
#  [u'@vigigu', u'google', u'it', u'simple', u'\n'],
#  [u'nerd', u'as', u'girl', u' ', u'\n'],
#  [u'leadcorp', u'media', u'@leadcorpmedia_', u' ', u'\n'],
#  [u'rt',
#   u'mackdrama1017',
#   u'chiemoney',
#   u'use',
#   u'google',
#   u'and',
#   u'learn',
#   u'how',
#   u'to',
#   u'\n'],
#  [u'@shaffieweru',
#   u'morning',
#   u'bro',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video',
#   u'i',
#   u'need',
#   u'yr',
#   u'help',
#   u'i',
#   u'be',
#   u'talented',
#   u'bt',
#   u'i',
#   u'lack',
#   u'a',
#   u'manager',
#   u'bro',
#   u'\n'],
#  [u'google', u'play', u'gift', u'card', u'code', u'\n'],
#  [u'claim',
#   u'your',
#   u'google',
#   u'play',
#   u'gift',
#   u'card',
#   u'code',
#   u'amazon',
#   u'itunes',
#   u'googl\u2026',
#   u'\n'],
#  [u'@rizsrug216',
#   u'@tpaquette_iid',
#   u'per',
#   u'sorry',
#   u'st.',
#   u'devs',
#   u'for',
#   u'the',
#   u'sport',
#   u'come',
#   u'to',
#   u'\n'],
#  [u'baseball', u'.039', u'\n'],
#  [u'football', u'.125', u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@politibunny',
#   u'@phillipjhill89',
#   u'you',
#   u'should',
#   u'go',
#   u'read',
#   u'a',
#   u'publish',
#   u'article',
#   u'that',
#   u'russell',
#   u'simmons',
#   u'write',
#   u'him',
#   u'google',
#   u'it',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'@moniimamz',
#   u'i',
#   u'know',
#   u'i',
#   u'saw',
#   u'it',
#   u'online',
#   u'like',
#   u'if',
#   u'u',
#   u'google',
#   u'the',
#   u'review',
#   u'for',
#   u'it',
#   u'\U0001f610',
#   u'\n'],
#  [u'rt',
#   u'@kamcb29',
#   u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'yayyyyy',
#   u'thanks',
#   u'for',
#   u'the',
#   u'follow',
#   u'@yeahhimafangirl',
#   u'\n'],
#  [u'i',
#   u'love',
#   u'your',
#   u'google',
#   u'plus',
#   u'page',
#   u'with',
#   u'the',
#   u'other',
#   u'girl',
#   u'\U0001f49c\U0001f606',
#   u'\n'],
#  [u'after',
#   u'i',
#   u'have',
#   u'google',
#   u'&amp',
#   u'read',
#   u'a',
#   u'ton',
#   u'of',
#   u'article',
#   u'on',
#   u'the',
#   u'same',
#   u'subject',
#   u'i',
#   u'remember',
#   u'i',
#   u'could',
#   u'have',
#   u'just',
#   u'search',
#   u'youtube',
#   u'for',
#   u'this',
#   u'shit',
#   u'\U0001f620',
#   u'\n'],
#  [u'week', u'2', u'power', u'rankings\U0001f608', u'\n'],
#  [u'rt',
#   u'@showerthoughtts',
#   u'apple',
#   u'have',
#   u'air',
#   u'amazon',
#   u'have',
#   u'fire',
#   u'google',
#   u'have',
#   u'earth',
#   u'why',
#   u'do',
#   u'not',
#   u'microsoft',
#   u'have',
#   u'water',
#   u'\n'],
#  [u'-look',
#   u'up',
#   u'on',
#   u'google',
#   u'mikexjeremy',
#   u'secretly-',
#   u'&lt;33',
#   u'@fnafschimdt,@mikeschmit10,]#senpaibot~',
#   u'\n'],
#  [u'rt',
#   u'@_silentbent_',
#   u'go',
#   u'support',
#   u'@dadeputy',
#   u'single',
#   u'it',
#   u"'",
#   u'okay',
#   u'feat',
#   u'@jaesongreen',
#   u'on',
#   u'itunes',
#   u'google\u2026',
#   u'\n'],
#  [u'hi', u'checkout', u'this', u'application', u'\n'],
#  [u'rt', u'@glotevo', u'nerd', u'as', u'girl', u' ', u'\n'],
#  [u'i',
#   u'be',
#   u'play',
#   u'my',
#   u'singing',
#   u'monsters',
#   u'check',
#   u'it',
#   u'out',
#   u'\n'],
#  [u'ever',
#   u'want',
#   u'to',
#   u'become',
#   u'a',
#   u'google',
#   u'small',
#   u'business',
#   u'advisor',
#   u'now',
#   u'you',
#   u'can',
#   u'\n'],
#  [u'check',
#   u'out',
#   u'@gcloudandroid',
#   u'never',
#   u'worry',
#   u'about',
#   u'lose',
#   u'your',
#   u'android',
#   u'device',
#   u'up',
#   u'to',
#   u'10',
#   u'gb',
#   u'free',
#   u'to',
#   u'backup',
#   u'\n'],
#  [u'top',
#   u'android',
#   u'apps',
#   u'without',
#   u'all',
#   u'the',
#   u'game',
#   u'reveal',
#   u'in',
#   u'hide',
#   u'google',
#   u'play',
#   u'store',
#   u'link',
#   u'android',
#   u'india',
#   u'\n'],
#  [u'rt',
#   u'@clashbabe',
#   u'th8',
#   u'50vs50',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'\n'],
#  [u'how',
#   u'to',
#   u'increase',
#   u'blog',
#   u'traffic',
#   u'with',
#   u'google',
#   u'plus',
#   u'blogging',
#   u'smm',
#   u'socialmedia',
#   u':officialchat\u2026',
#   u'\n'],
#  [u'relnews', u'\n'],
#  [u'                    ',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-the', u'daily', u'telegraph-', u'\n'],
#  [u'relnews', u'\n'],
#  [u'                    ',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u' ', u'-the', u'daily', u'telegraph-', u'\n'],
#  [u'new',
#   u'post',
#   u'google',
#   u'knowledge',
#   u'graph',
#   u'optimization',
#   u'strategies',
#   u'for',
#   u'the',
#   u'new',
#   u'year',
#   u'for',
#   u'infographic',
#   u'designers',
#   u'\n'],
#  [u'anyone',
#   u'else',
#   u'spend',
#   u'the',
#   u'entire',
#   u'time',
#   u'drive',
#   u'try',
#   u'to',
#   u'beat',
#   u'the',
#   u'original',
#   u'arrival',
#   u'time',
#   u'estimate',
#   u'from',
#   u'google',
#   u'maps',
#   u'\U0001f643',
#   u'\n'],
#  [u'design', u'font', u'of', u'the', u'day', u'mecka', u'design', u'\n'],
#  [u'google',
#   u'you',
#   u'have',
#   u'fail',
#   u'me',
#   u'for',
#   u'the',
#   u'first',
#   u'time',
#   u'why',
#   u'can',
#   u'not',
#   u'you',
#   u'tell',
#   u'me',
#   u'what',
#   u'these',
#   u'crystal',
#   u'be',
#   u'inside',
#   u'my',
#   u'plum',
#   u'\n'],
#  [u'rt', u'@rougek68', u'on', u'the', u'meaning', u'of', u'fascism', u'\n'],
#  [u'usa', u'israel', u'\n'],
#  [u'we', u"'re", u'all', u'fascist', u'now', u'\n'],
#  [u'time', u'u', u'kno\u2026', u'\n'],
#  [u'google', u'team2pm', u'\n'],
#  [u'rt',
#   u'@clashbabe',
#   u'th8',
#   u'50vs50',
#   u'come',
#   u'join',
#   u'the',
#   u'fun',
#   u'\n'],
#  [u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'compliment',
#   u'you',
#   u'\n'],
#  [u'rt',
#   u'@_rachaelmcclung',
#   u'brain',
#   u'go',
#   u'to',
#   u'sleep',
#   u'its',
#   u'10',
#   u'pm',
#   u'you',
#   u'now',
#   u'have',
#   u'a',
#   u'decent',
#   u'8',
#   u'hour',
#   u'of',
#   u'sleep',
#   u'\n'],
#  [u'me',
#   u'stay',
#   u'up',
#   u'to',
#   u'google',
#   u'different',
#   u'food',
#   u'recipe',
#   u'for\u2026',
#   u'\n'],
#  [u'rt',
#   u'google',
#   u'android',
#   u'n',
#   u'will',
#   u'not',
#   u'use',
#   u'oracle',
#   u"'s",
#   u' ',
#   u'java',
#   u'apis',
#   u' ',
#   u'gunjanraik',
#   u'\n'],
#  [u'rt',
#   u'android',
#   u'application',
#   u'relate',
#   u'to',
#   u'google',
#   u'map',
#   u'2',
#   u'by',
#   u'nsatheeshk',
#   u'need',
#   u'to',
#   u'update',
#   u'the',
#   u'android',
#   u'mobil',
#   u'\n'],
#  [u'my',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8',
#   u'out',
#   u'there',
#   u'\n'],
#  [u'oldrocks',
#   u'structuresleftbehind',
#   u'predeluge',
#   u'ancient',
#   u'microsculpture',
#   u'to',
#   u'massive',
#   u'face',
#   u'&amp',
#   u'shape',
#   u'iconography',
#   u'remain',
#   u'\n'],
#  [u'@imbruedjoint',
#   u'hector',
#   u'have',
#   u'softly',
#   u'tilt',
#   u'his',
#   u'head',
#   u'towards',
#   u'stuart',
#   u'in',
#   u'a',
#   u'confused',
#   u'sort',
#   u'of',
#   u'way',
#   u'what',
#   u"'",
#   u'google',
#   u'he',
#   u'could',
#   u'not',
#   u'possibly',
#   u'know',
#   u'what',
#   u'\n'],
#  [u'good',
#   u'domain',
#   u'possibility',
#   u'www',
#   u'west',
#   u'virginia',
#   u'its',
#   u'trending',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'here',
#   u'man',
#   u'@thereallogs1996',
#   u'when',
#   u'you',
#   u'talk',
#   u'about',
#   u'how',
#   u'the',
#   u'cubs',
#   u'win',
#   u'last',
#   u'year',
#   u' ',
#   u'\n'],
#  [u'google',
#   u'knowledge',
#   u'graph',
#   u'optimization',
#   u'strategies',
#   u'for',
#   u'the',
#   u'new',
#   u'year',
#   u'for',
#   u'infographic',
#   u'  ',
#   u'designer',
#   u'\n'],
#  [u'lebanonhashtag',
#   u'rt',
#   u'probrandz',
#   u'facebook',
#   u'open',
#   u'sources',
#   u'artificial',
#   u'intelligence',
#   u'servers',
#   u'before',
#   u'google',
#   u'|',
#   u're/code',
#   u'\n'],
#  [u'di\u2026', u'\n'],
#  [u'@r0thejan',
#   u'earn',
#   u'free',
#   u'google',
#   u'play',
#   u'and',
#   u'many',
#   u'more',
#   u'giftcards',
#   u'at',
#   u'our',
#   u'fresh',
#   u'publish',
#   u'website',
#   u'\n'],
#  [u'kalguntuku',
#   u'rt',
#   u'bunnymiilk',
#   u'rt',
#   u'30seclovelive',
#   u'rt',
#   u'to',
#   u'win',
#   u'30',
#   u'second',
#   u'of',
#   u'love',
#   u'live',
#   u'5k',
#   u'follower',
#   u'giveaway',
#   u'1',
#   u'$',
#   u'25',
#   u'itunes/google',
#   u'play',
#   u'gift',
#   u'ca\u2026',
#   u'\n'],
#  [u'rt',
#   u'@fortunemagazine',
#   u'here',
#   u'\u2019',
#   u'how',
#   u'google',
#   u'be',
#   u'take',
#   u'on',
#   u'uber',
#   u'in',
#   u'2016',
#   u'\n'],
#  [u'minecraft',
#   u'i',
#   u'google',
#   u'natural',
#   u'arch',
#   u'and',
#   u'a',
#   u'minecraft',
#   u'image',
#   u'pop',
#   u'up',
#   u'for',
#   u'a',
#   u'real',
#   u'geographical',
#   u'scenic',
#   u'spot',
#   u'by',
#   u'skandal\u2026',
#   u'\n'],
#  [u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'abo\u2026',
#   u'\n'],
#  [u'what',
#   u'each',
#   u'state',
#   u'google',
#   u'd',
#   u'more',
#   u'than',
#   u'me',
#   u'love',
#   u'picoftheday',
#   u'follow',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'google',
#   u'a',
#   u'wolf',
#   u'hybrid',
#   u'its',
#   u'my',
#   u'future',
#   u'dog',
#   u'\n'],
#  [u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'unlock',
#   u'a',
#   u'new',
#   u'area',
#   u'of',
#   u'my',
#   u'island',
#   u'gameinsight',
#   u'android',
#   u'androidgames',
#   u'\n'],
#  [u'get',
#   u'it',
#   u'google',
#   u"'s",
#   u'late',
#   u'free',
#   u'android',
#   u'wallpaper',
#   u'show',
#   u'useful',
#   u'phone',
#   u'android',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'reach',
#   u'level',
#   u'28',
#   u'i',
#   u'earn',
#   u'  ',
#   u'$',
#   u'123000',
#   u'and',
#   u'\u20ac3',
#   u'gameinsight',
#   u'androidgames',
#   u'android',
#   u'\n'],
#  [u'make',
#   u'sure',
#   u'your',
#   u'siwe',
#   u'ishkeeping',
#   u'xsers',
#   u'mn',
#   u'thxir',
#   u'prefer',
#   u'ver|ion',
#   u' ',
#   u'fkyourmwebsite',
#   u'for',
#   u'tceir',
#   u'entule',
#   u'vtsiq',
#   u'google',
#   u'webmcstervkx',
#   u'\n'],
#  [u'rt',
#   u'@ladybirdcoc',
#   u'my',
#   u'mini',
#   u'just',
#   u'go',
#   u'to',
#   u'th9',
#   u'\U0001f622',
#   u'but',
#   u'this',
#   u'will',
#   u'be',
#   u'a',
#   u'fun',
#   u'event',
#   u'for',
#   u'any',
#   u'th8',
#   u'out',
#   u'there',
#   u'\n'],
#  [u'nfl',
#   u'marshawnlynch',
#   u'2013',
#   u'nfc',
#   u'champ',
#   u'game',
#   u'marshawn',
#   u'lynch',
#   u'touchdown',
#   u'run',
#   u'seattle',
#   u'seahawks',
#   u'8x10',
#   u'photo',
#   u'seahawks',
#   u'google',
#   u'\n'],
#  [u'@chocolateluvah',
#   u'completely',
#   u'agree',
#   u'it',
#   u"'",
#   u'kill',
#   u'me',
#   u'not',
#   u'to',
#   u'google',
#   u'the',
#   u'case',
#   u'haha',
#   u'\n'],
#  [u'@jeddzn',
#   u'@ivanofficial__',
#   u'@picardonoel',
#   u'what',
#   u'',
#   u'that',
#   u'do',
#   u'nt',
#   u'ask',
#   u'me',
#   u'to',
#   u'google',
#   u'it',
#   u'\n'],
#  [u'rt',
#   u'@seosanjayupadhy',
#   u'alt',
#   u'+',
#   u'6',
#   u'....\u2660',
#   u'..s\xacpade',
#   u'alt',
#   u'+',
#   u'5',
#   u'....\u2663',
#   u'\xacclub',
#   u'alt',
#   u'+',
#   u'3',
#   u'\xacheart',
#   u'alt',
#   u'+',
#   u'4',
#   u'....\u2666',
#   u'\xacdiamond\u2026',
#   u'htt\u2026',
#   u'\n'],
#  [u'rt',
#   u'@chrismessina',
#   u'tell',
#   u'me',
#   u'that',
#   u'zuck',
#   u'be',
#   u'not',
#   u'plan',
#   u'to',
#   u'take',
#   u'on',
#   u'google',
#   u'with',
#   u'messenger',
#   u'convcomm',
#   u' ',
#   u'\n'],
#  [u'second',
#   u'when',
#   u'i',
#   u'be',
#   u'tweet',
#   u'i',
#   u'have',
#   u'always',
#   u'get',
#   u'my',
#   u'google',
#   u'docs',
#   u'open',
#   u'as',
#   u'well',
#   u'amwriting',
#   u'\n'],
#  [u'rt',
#   u'showerthoughtts',
#   u'apple',
#   u'have',
#   u'air',
#   u'amazon',
#   u'have',
#   u'fire',
#   u'google',
#   u'have',
#   u'earth',
#   u'why',
#   u'do',
#   u'not',
#   u'm\u2026',
#   u'\n'],
#  [u'@luckyberry96',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'@victoria_stee',
#   u'u',
#   u'+google',
#   u"'s",
#   u'instruction',
#   u'just',
#   u'save',
#   u'my',
#   u'life\U0001f618',
#   u'\n'],
#  [u'rt',
#   u'@kunalchoudhary_',
#   u'pathankot',
#   u'attack',
#   u'youth',
#   u'congress',
#   u'member',
#   u'burn',
#   u'sharifs',
#   u'effigy',
#   u'in',
#   u'bhopal',
#   u'@indiatoday',
#   u'\n'],
#  [u'@rajabrar\u2026', u'\n'],
#  [u'also',
#   u'here',
#   u'it',
#   u'be',
#   u'my',
#   u'revamped',
#   u'and',
#   u'much',
#   u'better',
#   u'got7',
#   u'primer',
#   u'share',
#   u'our',
#   u'boy',
#   u'with',
#   u'the',
#   u'world',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'new',
#   u'mobile',
#   u'apps',
#   u'on',
#   u'playstore',
#   u'android',
#   u'god',
#   u'of',
#   u'rome',
#   u'cut',
#   u'the',
#   u'rope',
#   u'gun',
#   u'simulator',
#   u'kitwall',
#   u'etc',
#   u'.check',
#   u'more',
#   u'on',
#   u'\n'],
#  [u'any', u'other', u'taker', u'\n'],
#  [u'googleexpertuk',
#   u'google',
#   u'support',
#   u'swedish',
#   u'chef',
#   u'from',
#   u'the',
#   u'muppets',
#   u'muppetsstudio',
#   u'internet',
#   u'\n'],
#  [u'eco', u'100', u'wk', u'10', u'chapter', u'18', u'homework', u'\n'],
#  [u'@winterfnmute665',
#   u'@rt_america',
#   u'look',
#   u'up',
#   u'militia',
#   u'too',
#   u'second',
#   u'definition',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'these',
#   u'term',
#   u'no',
#   u'matter',
#   u'how',
#   u'bad',
#   u'you',
#   u'want',
#   u'to',
#   u'\n'],
#  [u'kalguntuku',
#   u'rt',
#   u'bunnymiilk',
#   u'rt',
#   u'30seclovelive',
#   u'rt',
#   u'to',
#   u'win',
#   u'30',
#   u'second',
#   u'of',
#   u'love',
#   u'live',
#   u'5k',
#   u'follower',
#   u'giveaway',
#   u'1',
#   u'$',
#   u'25',
#   u'i\u2026',
#   u'\n'],
#  [u'@ohitsmrcreeper',
#   u'@sapphireginger',
#   u'oh',
#   u'thank',
#   u'god',
#   u'google',
#   u'translate',
#   u'be',
#   u'wrong',
#   u'\n'],
#  [u'rt',
#   u'@carlaliones',
#   u'\u2714tweetsheet\u27a1petitions',
#   u'part',
#   u'3\u2714',
#   u'support',
#   u'the',
#   u'fight',
#   u'against',
#   u'dog&amp;cat',
#   u'meatindustry',
#   u'in',
#   u'southkorea',
#   u'http\u2026',
#   u'\n'],
#  [u'google', u'maps', u'\n'],
#  [u'@xen_game',
#   u'google',
#   u'do',
#   u'not',
#   u'say',
#   u'what',
#   u'5',
#   u'out',
#   u'7',
#   u'mean',
#   u'why',
#   u'not',
#   u'7',
#   u'out',
#   u'of',
#   u'7',
#   u'\n'],
#  [u'@makingstarwar',
#   u'ugh',
#   u'the',
#   u'right',
#   u'sign',
#   u'mess',
#   u'up',
#   u'the',
#   u'link',
#   u'google',
#   u'force',
#   u'awaken',
#   u'70mm',
#   u'and',
#   u'the',
#   u'imax',
#   u'link',
#   u'should',
#   u'send',
#   u'you',
#   u'there',
#   u'\n'],
#  [u'rt',
#   u'@dinowoowife',
#   u'my',
#   u'bts',
#   u'2nd',
#   u'muster',
#   u'slogan',
#   u'\ub450\uadfc\uac74',
#   u'by',
#   u'visual',
#   u'shock',
#   u'@vshock1230',
#   u'\n'],
#  [u'lebanonhashtag',
#   u'rt',
#   u'probrandz',
#   u'facebook',
#   u'open',
#   u'sources',
#   u'artificial',
#   u'intelligence',
#   u'servers',
#   u'before',
#   u'google',
#   u'|',
#   u're/code',
#   u'\n'],
#  [u'di\u2026', u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'paypal',
#   u'me',
#   u'be',
#   u'so',
#   u'infuriating',
#   u'but',
#   u'i',
#   u'be',
#   u'use',
#   u'it',
#   u'anyway',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'ford',
#   u'add',
#   u'apple',
#   u'carplay',
#   u'and',
#   u'android',
#   u'auto',
#   u'to',
#   u'sync',
#   u'3',
#   u'google',
#   u'|',
#   u'\n'],
#  [u'best',
#   u'colour',
#   u'for',
#   u'zodiac',
#   u'sign',
#   u'in',
#   u'year',
#   u'2016',
#   u'\n'],
#  [u'\n'],
#  [u'@shaffieweru',
#   u'hi',
#   u'bro',
#   u'i',
#   u'need',
#   u'your',
#   u'help',
#   u'here',
#   u'be',
#   u'my',
#   u'new',
#   u'video..can',
#   u'you',
#   u'manage',
#   u'me',
#   u'bro',
#   u'\n'],
#  [u'try',
#   u'twitgrow',
#   u'for',
#   u'twitter',
#   u'get',
#   u'1000+',
#   u'real',
#   u'follower',
#   u'retweets',
#   u'and',
#   u'favorite',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'rt',
#   u'@lw',
#   u'how',
#   u'to',
#   u'be',
#   u'the',
#   u'person',
#   u'who',
#   u'never',
#   u'miss',
#   u'a',
#   u'deadline',
#   u'\n'],
#  [u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'abo\u2026',
#   u'\n'],
#  [u'rt',
#   u'@dinowoowife',
#   u'my',
#   u'jimin',
#   u'2016',
#   u'rise',
#   u'stock',
#   u'sale',
#   u'by',
#   u'miningful',
#   u'moment',
#   u'@miningfulmoment',
#   u'\u2665',
#   u'\n'],
#  [u'creativitybooster',
#   u'communicate',
#   u'stupid',
#   u'affiliate',
#   u'at',
#   u'google',
#   u'top',
#   u'10',
#   u'idea',
#   u'growthhacking',
#   u'blogging',
#   u'\n'],
#  [u'radio',
#   u'top40',
#   u'now',
#   u'play',
#   u'shut',
#   u'up',
#   u'stormzy',
#   u'apps',
#   u'apple',
#   u'google',
#   u'\n'],
#  [u'will',
#   u'google',
#   u'do',
#   u'one',
#   u'of',
#   u'those',
#   u'semantically',
#   u'aware',
#   u'auto',
#   u'answer',
#   u'if',
#   u'i',
#   u'search',
#   u'rza',
#   u'elo',
#   u'do',
#   u'not',
#   u'wanna',
#   u'be',
#   u'disappoint',
#   u'\n'],
#  [u'just',
#   u'like',
#   u'new',
#   u'college',
#   u'student',
#   u'be',
#   u'at',
#   u'risk',
#   u'for',
#   u'the',
#   u'freshman',
#   u'15',
#   u'google',
#   u'employee',
#   u'joke',
#   u'about',
#   u'the',
#   u'google',
#   u'15',
#   u'from',
#   u'all',
#   u'the',
#   u'snaks',
#   u'available',
#   u'\n'],
#  [u'me', u'af', u'\U0001f602\U0001f602\U0001f602', u'\n'],
#  [u'spare',
#   u'mark',
#   u'as',
#   u'respect',
#   u'the',
#   u'google',
#   u'android',
#   u'scum',
#   u'yourself',
#   u'april',
#   u'au',
#   u'pair',
#   u'self',
#   u'skacv',
#   u'\n'],
#  [u'google',
#   u'cardboard',
#   u'used',
#   u'by',
#   u'surgeon',
#   u'to',
#   u'perform',
#   u'heart',
#   u'surgery',
#   u'and',
#   u'saves',
#   u'a',
#   u'life',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'spend',
#   u'money',
#   u'saves',
#   u'you',
#   u'time',
#   u'and',
#   u'earns',
#   u'you',
#   u'more',
#   u'money',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'this',
#   u'house',
#   u'be',
#   u'sell',
#   u'dirt',
#   u'cheap',
#   u'the',
#   u'google',
#   u'maps',
#   u'picture',
#   u'explains',
#   u'exactly',
#   u'why',
#   u'\n'],
#  [u'google', u'have', u'no', u'chill', u'\n'],
#  [u'rt',
#   u'@got7style',
#   u'b2gether',
#   u'got7',
#   u'with',
#   u'b',
#   u'connect',
#   u'bracelet',
#   u'\n'],
#  [u'jb', u' ', u'jackson', u' ', u'teamgot7', u'got7style', u'\n'],
#  [u'\n'],
#  [u'woman', u'rise', u'in', u'hp', u'panchayat', u'politics', u'hp', u'\n'],
#  [u'police',
#   u'condemn',
#   u'facebook',
#   u'comment',
#   u'on',
#   u'mount',
#   u'maunganui',
#   u'new',
#   u'year',
#   u"'s",
#   u'eve',
#   u'page',
#   u'facebook',
#   u'\n'],
#  [u'wonder',
#   u'which',
#   u'food',
#   u'be',
#   u'healthier',
#   u'google',
#   u'have',
#   u'a',
#   u'tool',
#   u'for',
#   u'\n'],
#  [u'rt',
#   u'@f396',
#   u'iran',
#   u'blame',
#   u'america',
#   u'britain',
#   u'and',
#   u'zionist',
#   u'for',
#   u'nimr',
#   u'execution',
#   u'via',
#   u'\n'],
#  [u'@trp_takumi', u'reply', u'\n'],
#  [u'\n'],
#  [u'gunakan', u'lah', u'google', u'translate', u'lol', u'xd', u'\n'],
#  [u'lifehacker',
#   u'run',
#   u'windows',
#   u'on',
#   u'your',
#   u'mac',
#   u'virtualbox',
#   u'vs',
#   u'vmware',
#   u'fusion',
#   u'vs',
#   u'parallels',
#   u'\n'],
#  [u'the',
#   u'polar',
#   u'bears',
#   u'movie',
#   u'&amp',
#   u'tv',
#   u'on',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'become',
#   u'a',
#   u'google',
#   u'small',
#   u'business',
#   u'expert',
#   u'advisor',
#   u' ',
#   u'inboundmarketing',
#   u'feedly',
#   u'\n'],
#  [u'gang',
#   u'knock',
#   u'down',
#   u'cane',
#   u'grove',
#   u'man',
#   u'then',
#   u'beat',
#   u'him',
#   u'to',
#   u'death',
#   u'beat',
#   u'\n'],
#  [u'ohio',
#   u'state',
#   u'basketball',
#   u'win',
#   u'sixth',
#   u'straight',
#   u'beat',
#   u'illinois',
#   u'75',
#   u'73',
#   u'beat',
#   u'\n'],
#  [u'rt',
#   u'@newsycombinator',
#   u'google',
#   u'hp',
#   u'oracle',
#   u'join',
#   u'risc',
#   u'v',
#   u'open',
#   u'source',
#   u'processor',
#   u'core',
#   u'gain',
#   u'traction',
#   u'\n'],
#  [u'@_queenlioness_',
#   u'@justinrgrrb',
#   u'@mcdonald_wes',
#   u'sweet',
#   u'de',
#   u'lights',
#   u'bakery',
#   u'inc',
#   u'&lt;----',
#   u'this',
#   u'place',
#   u'google',
#   u'it',
#   u'a++++++',
#   u'\n'],
#  [u'rt',
#   u'@f396',
#   u'saudi',
#   u'arabia',
#   u'sever',
#   u'diplomatic',
#   u'tie',
#   u'with',
#   u'iran',
#   u'over',
#   u'embassy',
#   u'fire',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'people',
#   u'un',
#   u'follow',
#   u'you',
#   u'on',
#   u'social',
#   u'media',
#   u'platforms',
#   u' ',
#   u'quick',
#   u'cash',
#   u'\n'],
#  [u'@mrkenneyy',
#   u'i',
#   u'saw',
#   u'ur',
#   u'tweet',
#   u'no',
#   u'need',
#   u'for',
#   u'google',
#   u'lol',
#   u'it',
#   u"'",
#   u'a',
#   u'very',
#   u'large',
#   u'dog',
#   u'\n'],
#  [u'new',
#   u'google',
#   u'chat',
#   u'app',
#   u'could',
#   u'destroy',
#   u'facebook',
#   u'messenger',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'@lexicaaan',
#   u'me',
#   u'af',
#   u'\U0001f602\U0001f602\U0001f602',
#   u'\n'],
#  [u'radio',
#   u'90',
#   u'juice',
#   u'now',
#   u'play',
#   u'breathe',
#   u'radio',
#   u'edit',
#   u'midge',
#   u'ure',
#   u'apps',
#   u'apple',
#   u'google',
#   u'\n'],
#  [u'@sebast_lj',
#   u'@mcfaul',
#   u'@inna4848',
#   u'cause',
#   u'google',
#   u'translate',
#   u'it',
#   u'as',
#   u'return',
#   u'to',
#   u'california',
#   u'\n'],
#  [u'my',
#   u'google',
#   u'play',
#   u'account',
#   u'make',
#   u'me',
#   u'realize',
#   u'i',
#   u'be',
#   u'a',
#   u'dysfunctional',
#   u'teen',
#   u'with',
#   u'deep',
#   u'emotional',
#   u'scar',
#   u'\n'],
#  [u'late',
#   u'update',
#   u'brings',
#   u'new',
#   u'skills',
#   u'to',
#   u'the',
#   u'amazonecho',
#   u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@f396',
#   u'iran',
#   u'have',
#   u'a',
#   u'long',
#   u'record',
#   u'in',
#   u'attack',
#   u'foreign',
#   u'diplomatic',
#   u'mission',
#   u'saudi',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'algorith',
#   u' ',
#   u'what',
#   u'a\u2026',
#   u'\n'],
#  [u'rt',
#   u'masterminddbs',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'al\u2026',
#   u'\n'],
#  [u'just', u'like', u'real', u'life', u'\n'],
#  [u'i',
#   u'like',
#   u'a',
#   u'@youtube',
#   u'video',
#   u'10',
#   u'thing',
#   u'you',
#   u'should',
#   u'never',
#   u'google',
#   u'warning',
#   u'gross',
#   u'\n'],
#  [u'here',
#   u'be',
#   u'what',
#   u'happen',
#   u'to',
#   u'@_snat',
#   u'when',
#   u'he',
#   u'can',
#   u'not',
#   u'access',
#   u'google',
#   u'translate',
#   u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@kappa_kappa',
#   u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'c\u2026',
#   u'\n'],
#  [u'rt',
#   u'@carlaliones',
#   u'\u2714tweetsheet\u27a1petitions',
#   u'part',
#   u'3\u2714',
#   u'support',
#   u'the',
#   u'fight',
#   u'against',
#   u'dog&amp;cat',
#   u'meatindustry',
#   u'in',
#   u'southkorea',
#   u'http\u2026',
#   u'\n'],
#  [u'rt',
#   u'seotraversecity',
#   u'shenbrood',
#   u'what',
#   u"'",
#   u'your',
#   u'great',
#   u'digitalmarketing',
#   u'contentmarketing',
#   u'blunder',
#   u' ',
#   u'well',
#   u'for',
#   u'me',
#   u'it',
#   u"'",
#   u'the',
#   u'ever',
#   u'change',
#   u'google',
#   u'\n'],
#  [u'rt', u'@ninelivesf', u'a', u'kitten', u'call', u'wanda', u'\n'],
#  [u'many',
#   u'of',
#   u'you',
#   u'have',
#   u'ask',
#   u'how',
#   u'wanda',
#   u'come',
#   u'to',
#   u'be',
#   u'at',
#   u'nine',
#   u'lives',
#   u'foundation',
#   u'pair',
#   u'up',
#   u'with\u2026',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'rt',
#   u'@ceektechnology',
#   u'google',
#   u'nexus6p',
#   u'review',
#   u'android',
#   u'overdose',
#   u'via',
#   u'@bgdftw',
#   u'\n'],
#  [u'rt',
#   u'@got7style',
#   u'b2gether',
#   u'got7',
#   u'with',
#   u'b',
#   u'connect',
#   u'bracelet',
#   u'\n'],
#  [u'jb', u' ', u'jackson', u' ', u'teamgot7', u'got7style', u'\n'],
#  [u'\n'],
#  [u'irulu',
#   u'tablet',
#   u'pc',
#   u'expro',
#   u'x1s',
#   u'7',
#   u'8gb/1gb',
#   u'google',
#   u'android',
#   u'4.4',
#   u'kitkat',
#   u'quad',
#   u'core',
#   u'black',
#   u'bid',
#   u'now',
#   u'\n'],
#  [u'new',
#   u'irulu',
#   u'7',
#   u'purple',
#   u'16gb',
#   u'google',
#   u'android',
#   u'4.4',
#   u'kitkat',
#   u'expro',
#   u'x1a',
#   u'hd',
#   u'tablet',
#   u'quad',
#   u'core',
#   u'bid',
#   u'now\u2026',
#   u'\n'],
#  [u'this',
#   u'house',
#   u'be',
#   u'for',
#   u'sale',
#   u'and',
#   u'what',
#   u'google',
#   u'maps',
#   u'caught',
#   u'inside',
#   u'explains',
#   u'the',
#   u'c',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'an',
#   u'apple',
#   u'a',
#   u'day',
#   u'android',
#   u'androidgames',
#   u'gameinsight',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'an',
#   u'apple',
#   u'a',
#   u'day',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'rt',
#   u'@dronelaw',
#   u'status',
#   u'report',
#   u'on',
#   u'the',
#   u'ntia',
#   u'multi',
#   u'stakeholder',
#   u'drone',
#   u'privacy',
#   u'process',
#   u'\n'],
#  [u'braided',
#   u'beard',
#   u'google',
#   u'search',
#   u'fashion',
#   u'mensfashion',
#   u'style',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'google', u'and', u'share', u'your', u'radiation', u'this', u'week', u'\n'],
#  [u'and',
#   u'tell',
#   u'your',
#   u'friend',
#   u'and',
#   u'neighbor',
#   u'your',
#   u'government',
#   u'already',
#   u'know',
#   u'\n'],
#  [u'we', u'\n'],
#  [u'g+',
#   u'somethings',
#   u'change',
#   u'as',
#   u'you',
#   u'no',
#   u'longer',
#   u'want',
#   u'to',
#   u'live',
#   u'within',
#   u'the',
#   u'same',
#   u'dusty',
#   u'hallway',
#   u' ',
#   u'thing',
#   u'be',
#   u'that',
#   u'as',
#   u'you',
#   u'clean',
#   u'up\u2026',
#   u'\n'],
#  [u'texas',
#   u'college',
#   u'student',
#   u'kill',
#   u'in',
#   u'new',
#   u'year',
#   u"'s",
#   u'eve',
#   u'shooting',
#   u'cnn',
#   u'international',
#   u'\n'],
#  [u'\n'],
#  [u'check',
#   u'out',
#   u'this',
#   u'page',
#   u'for',
#   u'the',
#   u'hot',
#   u'music',
#   u'trend',
#   u'and',
#   u'more',
#   u'search',
#   u'your',
#   u'favorite',
#   u'music',
#   u'2',
#   u'\n'],
#  [u'hey', u'check', u'out', u'these', u'2016', u'amazon', u'tip', u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'rt', u'@gopof_idiot', u'@jeanettej', u'\n'],
#  [u'none', u'but', u'bernie', u'do', u'\n'],
#  [u'\n'],
#  [u'seem',
#   u'like',
#   u'my',
#   u'bos',
#   u'be',
#   u'interested',
#   u'enough',
#   u'in',
#   u'chen',
#   u'he',
#   u'just',
#   u'google',
#   u'chen',
#   u"'s",
#   u'pic',
#   u'and',
#   u'show',
#   u'it',
#   u'to',
#   u'me',
#   u'be',
#   u'this',
#   u'chen',
#   u'he',
#   u'look',
#   u'like',
#   u'pondan',
#   u'\n'],
#  [u'rt',
#   u'@pyprecord',
#   u'look',
#   u'us',
#   u'up',
#   u'on',
#   u'itunes',
#   u'just',
#   u'google',
#   u'the',
#   u'name',
#   u'popcorn',
#   u'pyp',
#   u'or',
#   u'come',
#   u'to',
#   u'nyc',
#   u'and',
#   u'ask',
#   u'for',
#   u'me',
#   u'\n'],
#  [u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'these',
#   u'term',
#   u'no',
#   u'matter',
#   u'how',
#   u'bad',
#   u'you',
#   u'want',
#   u'to',
#   u'\n'],
#  [u'@hadley_delducaa',
#   u'yeah',
#   u'but',
#   u'its',
#   u'worth',
#   u'a',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'@darkenedsight',
#   u'taylor',
#   u"'s",
#   u'gonna',
#   u'punch',
#   u'me',
#   u'now',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'search',
#   u'how',
#   u'to',
#   u'act',
#   u'as',
#   u'if',
#   u'it',
#   u'hurt',
#   u'brb',
#   u'\U0001f607\U0001f606',
#   u'\n'],
#  [u'pluralsight',
#   u'get',
#   u'start',
#   u'with',
#   u'google',
#   u'play',
#   u'in',
#   u'app',
#   u'billing',
#   u'\n'],
#  [u'@seedchan',
#   u'ill',
#   u'send',
#   u'you',
#   u'your',
#   u'card',
#   u'from',
#   u'tw',
#   u'\n'],
#  [u'not', u'even', u'google', u'can', u'help', u'\n'],
#  [u'not',
#   u'gonna',
#   u'lie',
#   u'i',
#   u'just',
#   u'type',
#   u'what',
#   u'to',
#   u'wear',
#   u'when',
#   u'it',
#   u"'",
#   u'-15',
#   u'degree',
#   u'on',
#   u'the',
#   u'outside',
#   u'in',
#   u'google',
#   u'\n'],
#  [u'samsung',
#   u'dear',
#   u'samsung',
#   u'i',
#   u'be',
#   u'very',
#   u'annoyed',
#   u'i',
#   u'can',
#   u'not',
#   u'revert',
#   u'to',
#   u'kitkat',
#   u'from',
#   u'lollipop',
#   u'i',
#   u'have',
#   u'contact',
#   u'google',
#   u'my',
#   u'provider',
#   u'opt',
#   u'\n'],
#  [u'check', u'out', u'gosford', u'park', u'on', u'hoopladigital', u'\n'],
#  [u'british', u'mystery', u'robert', u'altman', u'great', u'aleta', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'eco',
#   u'100',
#   u'wk',
#   u'10',
#   u'quiz',
#   u'chapters',
#   u'16',
#   u'and',
#   u'17',
#   u'\n'],
#  [u'@2pmphilippine', u'pls', u'help', u'rt', u'^_^', u'\n'],
#  [u'google',
#   u"'s",
#   u'ceo',
#   u'think',
#   u'vietnam',
#   u'home',
#   u'to',
#   u'the',
#   u'next',
#   u'big',
#   u'startup',
#   u'scene',
#   u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'get', u'your', u'song', u'on', u'itunes/google', u'play', u'etc', u'\n'],
#  [u'rt',
#   u'@beautiigirl',
#   u'this',
#   u'house',
#   u'be',
#   u'for',
#   u'sale',
#   u'cheap',
#   u'when',
#   u'you',
#   u'see',
#   u'what',
#   u'google',
#   u'maps',
#   u'caught',
#   u'you',
#   u'will',
#   u'see',
#   u'why',
#   u'\n'],
#  [u'@occamsboner',
#   u'@jonathanchait',
#   u'instead',
#   u'of',
#   u'ask',
#   u'everyone',
#   u'on',
#   u'twitter',
#   u' ',
#   u'why',
#   u'do',
#   u'not',
#   u'you',
#   u'google',
#   u'it',
#   u'weirdo',
#   u'\n'],
#  [u'what',
#   u'google',
#   u'say',
#   u'about',
#   u'seo',
#   u'in',
#   u'2016',
#   u'webpronews',
#   u'\n'],
#  [u'gandalf',
#   u'=',
#   u'google',
#   u'map',
#   u'gollum',
#   u'=',
#   u'apple',
#   u'map',
#   u'\n'],
#  [u'you',
#   u"'re",
#   u'not',
#   u'go',
#   u'to',
#   u'get',
#   u'away',
#   u'with',
#   u'this',
#   u'mr.',
#   u'google',
#   u'search',
#   u'\n'],
#  [u'rt',
#   u'@stephen_mcd',
#   u'django',
#   u'1.9',
#   u'support',
#   u'just',
#   u'land',
#   u'in',
#   u'mezzanine',
#   u'please',
#   u'help',
#   u'test',
#   u'it',
#   u'django',
#   u'\n'],
#  [u'try',
#   u'tunnelbear',
#   u'for',
#   u'  ',
#   u'chrome',
#   u'  ',
#   u'to',
#   u'browse',
#   u'like',
#   u'you',
#   u"'re",
#   u'in',
#   u'another',
#   u'country',
#   u'  ',
#   u'  ',
#   u'@thetunnelbear',
#   u'  ',
#   u'\n'],
#  [u'2060',
#   u'little',
#   u'red',
#   u'schoolhouse',
#   u'slat',
#   u'open',
#   u'house',
#   u'jan.',
#   u'9',
#   u'wicked',
#   u'local',
#   u'bellingham',
#   u'\n'],
#  [u'rt',
#   u'@wearableguru',
#   u'google',
#   u'glass',
#   u'live',
#   u'see',
#   u'the',
#   u'leak',
#   u'photo',
#   u'of',
#   u'the',
#   u'next',
#   u'version',
#   u'wearabletech',
#   u'wearables',
#   u'\n'],
#  [u'the', u'papi', u'ep', u'$', u'3.99', u'on', u'google', u'play', u'\n'],
#  [u'\n'],
#  [u'whn',
#   u'ur',
#   u'fnished',
#   u'wth',
#   u'an',
#   u'essay',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'into',
#   u'google',
#   u'translate',
#   u'and',
#   u'lsten',
#   u'to',
#   u'it',
#   u'its',
#   u'the',
#   u'easy',
#   u'way',
#   u'to',
#   u'find',
#   u'mistake',
#   u'showtimetrabahula',
#   u'\n'],
#  [u'eminem', u'not', u'afraid', u'\n'],
#  [u'google',
#   u'defeats',
#   u'copyright',
#   u'lawsuit',
#   u'over',
#   u'waze',
#   u'data',
#   u'forbes',
#   u'cross',
#   u'post',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'try',
#   u'to',
#   u'google',
#   u'oh',
#   u'yeah',
#   u'eat',
#   u'that',
#   u'bible',
#   u'for',
#   u'whatever',
#   u'reason',
#   u'without',
#   u'die',
#   u'\n'],
#  [u'technique',
#   u'of',
#   u'teach',
#   u'arabic',
#   u' ',
#   u'as',
#   u'a',
#   u'foreign',
#   u'language',
#   u'through',
#   u'constructivist',
#   u'paradigm',
#   u'malaysian',
#   u'perspective',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'rt', u'@gopof_idiot', u'@libertea2012', u'\n'],
#  [u'let',
#   u'help',
#   u'bernie',
#   u'get',
#   u'his',
#   u'message',
#   u'out',
#   u'since',
#   u'the',
#   u'medium',
#   u'be',
#   u'not',
#   u'help',
#   u'him',
#   u'like',
#   u'they',
#   u'r',
#   u'hillary',
#   u'&amp',
#   u'trump',
#   u'https:\u2026',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'now',
#   u'an',
#   u'e',
#   u'list',
#   u'celebrity',
#   u'in',
#   u'kim',
#   u'kardashian',
#   u'hollywood',
#   u'you',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'android',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'native',
#   u'american',
#   u'flute',
#   u'music',
#   u'meditation',
#   u'music',
#   u'for',
#   u'shamanic',
#   u'astral',
#   u'projection',
#   u'healing',
#   u'music',
#   u'\n'],
#  [u'rt',
#   u'@ezralevant',
#   u'here',
#   u"'",
#   u'why',
#   u'i',
#   u'be',
#   u'worried',
#   u'about',
#   u'censorship',
#   u'from',
#   u'@google',
#   u'@twitter',
#   u'&amp',
#   u'@facebook',
#   u'in',
#   u'2016',
#   u'because',
#   u'they',
#   u'say',
#   u'they',
#   u'will',
#   u'do',
#   u'it',
#   u'https:/\u2026',
#   u'\n'],
#  [u'course',
#   u'material',
#   u'for',
#   u'statistics',
#   u'the',
#   u'easier',
#   u'way',
#   u'with',
#   u'r',
#   u'rstats',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'3',
#   u'big',
#   u'lessons',
#   u'from',
#   u'3',
#   u'successful',
#   u'entrepreneurs',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'google', u'puckle', u'gun', u'\n'],
#  [u'hip',
#   u'hop',
#   u'alumni',
#   u'hha',
#   u'@google',
#   u'blogger',
#   u'&amp',
#   u'hha',
#   u'@youtube',
#   u'channel',
#   u'2016',
#   u'\n'],
#  [u'@rustybrick',
#   u'sir',
#   u'please',
#   u'tell',
#   u'me',
#   u'late',
#   u'@google',
#   u'algorithm',
#   u'in',
#   u'2016',
#   u'\n'],
#  [u'@kappa_kappa',
#   u'you',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'for',
#   u'real',
#   u'\n'],
#  [u'2057',
#   u'paul',
#   u'jacoulet',
#   u"'s",
#   u'widowed',
#   u'mother',
#   u'remarry',
#   u'and',
#   u'settle',
#   u'in',
#   u'korea',
#   u'his',
#   u'maine',
#   u'antique',
#   u'digest',
#   u'\n'],
#  [u'rt',
#   u'@abogomolov',
#   u'new',
#   u'in',
#   u'symfony',
#   u'2.8',
#   u'dx',
#   u'improvements',
#   u'\n'],
#  [u'\n'],
#  [u'symfony', u'\n'],
#  [u'@georgina944',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'phase',
#   u'one',
#   u'xf',
#   u'100mp',
#   u'use',
#   u'similar',
#   u'a7rii',
#   u'sensor',
#   u'tech',
#   u'first',
#   u'short',
#   u'image',
#   u'test',
#   u'impression',
#   u'|\u2026',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'eminem', u'the', u'real', u'slim', u'shady', u'edited', u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u'@makeuseof',
#   u'giveaway',
#   u'competition',
#   u'\n'],
#  [u'rt',
#   u'@realgoai',
#   u'when',
#   u'you',
#   u'google',
#   u'one',
#   u'question',
#   u'and',
#   u'find',
#   u'a',
#   u'quizlet',
#   u'for',
#   u'the',
#   u'whole',
#   u'test',
#   u'\n'],
#  [u'rt',
#   u'@teropa',
#   u'google',
#   u'analytics',
#   u'tell',
#   u'me',
#   u'the',
#   u'full',
#   u'stack',
#   u'redux',
#   u'tutorial',
#   u'have',
#   u'pass',
#   u'110k',
#   u'visitor',
#   u'that',
#   u'\u2019s',
#   u'crazy',
#   u'\n'],
#  [u'rt', u'@mikealbers23', u'great', u'new', u'workout', u'app', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'workout', u'fitness', u'gym', u'exercise', u'health', u'\n'],
#  [u'downtonabbey', u'quickworkout', u'http\u2026', u'\n'],
#  [u'@lawwrah',
#   u'@kla_anne33',
#   u'@itsothquote',
#   u'do',
#   u'not',
#   u'google',
#   u'any',
#   u'of',
#   u'it',
#   u'i',
#   u'always',
#   u'make',
#   u'that',
#   u'mistake',
#   u'still',
#   u'so',
#   u'good',
#   u'though',
#   u'\u2764\ufe0f',
#   u'\n'],
#  [u'@aizanzenzon',
#   u'go',
#   u'google',
#   u'about',
#   u'it',
#   u'and',
#   u'whatsapp',
#   u'me',
#   u'we',
#   u'can',
#   u'always',
#   u'plan',
#   u'\U0001f609',
#   u'\n'],
#  [u'iphone',
#   u'and',
#   u'ipad',
#   u'price',
#   u'go',
#   u'up',
#   u'in',
#   u'germany',
#   u'due',
#   u'to',
#   u'country',
#   u"'s",
#   u'private',
#   u'copying',
#   u'fee',
#   u'\n'],
#  [u'wedding',
#   u'gown',
#   u'survive',
#   u'tornado',
#   u'illinois',
#   u'farmer',
#   u'help',
#   u'reunite',
#   u'bride',
#   u'with',
#   u'ktrk',
#   u'tv',
#   u'\n'],
#  [u'@gauravpandhi',
#   u'@zubinaahmad',
#   u'@samarg_uvaach',
#   u'@reviewero',
#   u'if',
#   u'u',
#   u'want',
#   u'to',
#   u'play',
#   u'dirty',
#   u'politics',
#   u'then',
#   u'their',
#   u'r',
#   u'enough',
#   u'to',
#   u'be',
#   u'find',
#   u'on',
#   u'google',
#   u'against',
#   u'bjp',
#   u'\n'],
#  [u'fuse',
#   u'location',
#   u'provider',
#   u'in',
#   u'google',
#   u'play',
#   u'services8.4',
#   u'provide',
#   u'location',
#   u'to',
#   u'an',
#   u'app.https://t.co/mrvkmesqgd',
#   u'\n'],
#  [u'developer', u'\n'],
#  [u'turn',
#   u'your',
#   u'phone',
#   u'into',
#   u'a',
#   u'lightsaber',
#   u'with',
#   u'this',
#   u'mind',
#   u'blow',
#   u'google',
#   u'chrome',
#   u'experiment',
#   u'starwars',
#   u'\n'],
#  [u'@hollyheatbeat',
#   u'go',
#   u'to',
#   u'this',
#   u'website',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'in',
#   u'twitter',
#   u'tweet',
#   u'more',
#   u'for',
#   u'teamseventeen',
#   u'\n'],
#  [u'twitpane', u'  ', u'\n'],
#  [u'from',
#   u'digital',
#   u'disappointment',
#   u'tothe',
#   u'end',
#   u'of',
#   u'the',
#   u'app',
#   u'era',
#   u'here',
#   u'be',
#   u'eight',
#   u'trends',
#   u'for',
#   u'\n'],
#  [u'rt', u'@senyora', u'dam', u'handa', u'ah', u'google', u'\n'],
#  [u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'themeforest',
#   u'be',
#   u'awesome',
#   u'for',
#   u'buy',
#   u'custom',
#   u'templates',
#   u' ',
#   u'work',
#   u'from',
#   u'home',
#   u'\n'],
#  [u'rt',
#   u'@artfulkis',
#   u'i',
#   u'google',
#   u'earthed',
#   u'my',
#   u'house',
#   u'and',
#   u'i',
#   u'saw',
#   u'something',
#   u'in',
#   u'my',
#   u'window',
#   u'and',
#   u'its',
#   u'louis',
#   u'cardboard',
#   u'cut',
#   u'out',
#   u'\n'],
#  [u'@ckirubi', u'hello', u'sir', u'watch', u'my', u'new', u'video', u'\n'],
#  [u'rt', u'@realshigerum', u'don\u2019t', u'google', u'sexy', u'yoshi', u'\n'],
#  [u'rt',
#   u'fashion',
#   u'apparel',
#   u'and',
#   u'retail',
#   u'stock',
#   u'end',
#   u'2015',
#   u'with',
#   u'whimper',
#   u'wwd',
#   u'\n'],
#  [u'\n'],
#  [u'fashion', u'apparel', u'and', u'ret\u2026', u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'rt',
#   u'famina',
#   u'europe',
#   u'could',
#   u'produce',
#   u'a',
#   u'facebook',
#   u'and',
#   u'the',
#   u'google',
#   u'of',
#   u'healthcare',
#   u'impact',
#   u'socbiz',
#   u'biz',
#   u'\n'],
#  [u'@lee_yooyoung_', u'translate', u'to', u'google', u'then', u':"c', u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@jasondemanzo',
#   u'with',
#   u'as',
#   u'much',
#   u'as',
#   u'they',
#   u'pay',
#   u'in',
#   u'luxury',
#   u'tax',
#   u'&amp',
#   u'rev',
#   u'from',
#   u'the',
#   u'new',
#   u'cable',
#   u'deal',
#   u'kobe',
#   u'deal',
#   u'be',
#   u'not',
#   u'a',
#   u'problem',
#   u'you',
#   u'go',
#   u'google',
#   u'something',
#   u'moron',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'i',
#   u'have',
#   u'enter',
#   u'to',
#   u'win',
#   u'a',
#   u'google',
#   u'nexus',
#   u'6p',
#   u'from',
#   u' ',
#   u'   ',
#   u'\n'],
#  [u'google',
#   u'\u2019s',
#   u'schmidt',
#   u'say',
#   u'this',
#   u'nation',
#   u'lead',
#   u'e',
#   u'commerce',
#   u'news',
#   u'market',
#   u'business',
#   u'\n'],
#  [u'the',
#   u'nexus',
#   u'reload',
#   u'google',
#   u'nexus',
#   u'5x',
#   u'&amp',
#   u'6p',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'how',
#   u'to',
#   u'overcome',
#   u'isolation',
#   u'while',
#   u'you',
#   u'make',
#   u'money',
#   u'online',
#   u' ',
#   u'easy',
#   u'money',
#   u'\n'],
#  [u'fire', u'event', u'e017', u'runnels', u'east', u'dr', u'23:29', u'\n'],
#  [u'automatic',
#   u'alarm',
#   u'e011',
#   u'birdsall',
#   u'st',
#   u'washington',
#   u'ave',
#   u'23:27',
#   u'\n'],
#  [u'@andrearene',
#   u'@johntdrake',
#   u'i',
#   u'honestly',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'watch',
#   u'captain',
#   u'ron',
#   u'instead',
#   u'\n'],
#  [u'surprising',
#   u'amount',
#   u'of',
#   u'result',
#   u'on',
#   u'google',
#   u'search',
#   u'for',
#   u'alien',
#   u'with',
#   u'a',
#   u'comb',
#   u'over',
#   u'say',
#   u'it',
#   u'all',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@koolkaattt_',
#   u'what',
#   u'about',
#   u'your',
#   u'google',
#   u'docs?\U0001f602',
#   u'\n'],
#  [u'rt',
#   u'@kappa_kappa',
#   u'the',
#   u'first',
#   u'time',
#   u'someone',
#   u'comment',
#   u'schwing',
#   u'on',
#   u'one',
#   u'of',
#   u'my',
#   u'selfies',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'what',
#   u'it',
#   u'be',
#   u'it',
#   u"'",
#   u'basically',
#   u'an',
#   u'old',
#   u'guy',
#   u'c\u2026',
#   u'\n'],
#  [u'fiverrworks',
#   u'use',
#   u'this',
#   u'service',
#   u'to',
#   u'make',
#   u'lot',
#   u'of',
#   u'money',
#   u'by',
#   u'google',
#   u'read',
#   u'more',
#   u'fiverr',
#   u'se\u2026',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'ringleader', u'by', u'public', u'memory', u'nowplaying', u'beats1', u'\n'],
#  [u'try',
#   u'subscriber',
#   u'for',
#   u'youtube',
#   u' ',
#   u'get',
#   u'1000+',
#   u'real',
#   u'subscriber',
#   u'for',
#   u'your',
#   u'youtube',
#   u'channel',
#   u'google',
#   u'play:https://t.co/dxiw10zydv',
#   u'\n'],
#  [u'fiverrsociall',
#   u'use',
#   u'this',
#   u'service',
#   u'to',
#   u'make',
#   u'lot',
#   u'of',
#   u'money',
#   u'by',
#   u'google',
#   u'read',
#   u'more',
#   u'fiverr',
#   u'\n'],
#  [u'trendy', u'and', u'fashionable', u'\n'],
#  [u'rt',
#   u'@movylent',
#   u'\U0001f506',
#   u'best',
#   u'of',
#   u'2015',
#   u'how',
#   u'valve',
#   u"'s",
#   u'pay',
#   u'mod',
#   u'program',
#   u'implode',
#   u'in',
#   u'four',
#   u'day',
#   u'androidgames',
#   u'\n'],
#  [u'more', u'at', u'\n'],
#  [u'traffic',
#   u'stop',
#   u'at',
#   u's',
#   u'bell',
#   u'ave',
#   u'&amp',
#   u'e',
#   u'7th',
#   u'st',
#   u'shawnee',
#   u'\n'],
#  [u'eco',
#   u'100',
#   u'wk',
#   u'11',
#   u'final',
#   u'exam',
#   u'part',
#   u'i',
#   u'&amp',
#   u'ii',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'tiny',
#   u'village',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'go', u'analysis', u'use', u'clusterprofiler', u'rstats', u'\n'],
#  [u'the',
#   u'device',
#   u'apps',
#   u'and',
#   u'accessory',
#   u'i',
#   u'use',
#   u'most',
#   u'in',
#   u'2015',
#   u'\n'],
#  [u'morgan', u'monday', u'\n'],
#  [u'\n'],
#  [u'congress', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'english', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'german', u'\n'],
#  [u'\n'],
#  [u'@vivieennne',
#   u'its',
#   u'always',
#   u'tough',
#   u'get',
#   u'diagnose',
#   u'by',
#   u'google',
#   u'and',
#   u'greys',
#   u'we',
#   u'be',
#   u'here',
#   u'for',
#   u'you',
#   u'\n'],
#  [u'what',
#   u"'",
#   u'the',
#   u'best',
#   u'place',
#   u'to',
#   u'hide',
#   u'evidence',
#   u'page',
#   u'2',
#   u'of',
#   u'google',
#   u'nobody',
#   u'will',
#   u'look',
#   u'there',
#   u'seo',
#   u'joke',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'you',
#   u'should',
#   u'consider',
#   u'deep',
#   u'link',
#   u'to',
#   u'build',
#   u'authority',
#   u' ',
#   u'make',
#   u'fast',
#   u'cash',
#   u'\n'],
#  [u'rt', u'@harry_style', u'1d', u'day', u'innit', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@joshgrigorean',
#   u'google',
#   u'the',
#   u'definition',
#   u'of',
#   u'terrorism',
#   u'\n'],
#  [u'tip',
#   u'pass',
#   u'process',
#   u'in',
#   u'order',
#   u'to',
#   u'issue',
#   u'diagonal',
#   u'as',
#   u'much',
#   u'as',
#   u'it',
#   u'wantage',
#   u'plus',
#   u'google',
#   u'lmacrfzq',
#   u'\n'],
#  [u'so',
#   u'when',
#   u'i',
#   u'get',
#   u'the',
#   u'worm',
#   u'i',
#   u'have',
#   u'to',
#   u'google',
#   u'it',
#   u'because',
#   u'i',
#   u'be',
#   u'like',
#   u'what',
#   u'in',
#   u'the',
#   u'fcuk',
#   u'this',
#   u'actually',
#   u'happen',
#   u'forreal',
#   u'i',
#   u'think',
#   u'just',
#   u'some',
#   u'movieish',
#   u'\n'],
#  [u'i',
#   u'type',
#   u'fat',
#   u'domino',
#   u'behind',
#   u'the',
#   u'scenes',
#   u'into',
#   u'that',
#   u'there',
#   u'google',
#   u'and',
#   u'saw',
#   u'myself',
#   u' ',
#   u'umm',
#   u'ok',
#   u'\U0001f633\U0001f914\u2026',
#   u'\n'],
#  [u'rt',
#   u'@themoneygenie',
#   u'why',
#   u'you',
#   u'should',
#   u'love',
#   u'twitter',
#   u'advertising',
#   u' ',
#   u'make',
#   u'fast',
#   u'cash',
#   u'\n'],
#  [u'zspirov',
#   u'rt',
#   u'mikealbers23',
#   u'great',
#   u'new',
#   u'workout',
#   u'app',
#   u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'workout', u'fitness', u'gym', u'exercise', u'health', u'\n'],
#  [u'downtonabbey', u'quickwor\u2026', u'\n'],
#  [u'new',
#   u'psa',
#   u'urge',
#   u'action',
#   u'on',
#   u'grow',
#   u'medical',
#   u'marijuana',
#   u'in',
#   u'state',
#   u'wxia',
#   u'tv',
#   u'potbot',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'the',
#   u'federal',
#   u'ban',
#   u'on',
#   u'medical',
#   u'marijuana',
#   u'be',
#   u'not',
#   u'lift',
#   u'reason',
#   u'blog',
#   u'potbot',
#   u'\n'],
#  [u'rt',
#   u'@chrisbrown',
#   u'download',
#   u'royalty',
#   u'on',
#   u'google',
#   u'play',
#   u'today',
#   u'\n'],
#  [u'physician',
#   u'want',
#   u'robust',
#   u'study',
#   u'on',
#   u'medical',
#   u'marijuana',
#   u'use',
#   u'pittsburgh',
#   u'post',
#   u'gazette',
#   u'potbot',
#   u'\n'],
#  [u'before',
#   u'go',
#   u'to',
#   u'the',
#   u'gym',
#   u'google',
#   u'arnold',
#   u'schwarzenegger',
#   u'shirtless',
#   u'recent',
#   u'click',
#   u'image',
#   u'and',
#   u'stay',
#   u'home',
#   u'instead',
#   u'\n'],
#  [u'rt',
#   u'@alingtutan',
#   u'whn',
#   u'ur',
#   u'fnished',
#   u'wth',
#   u'an',
#   u'essay',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'into',
#   u'google',
#   u'translate',
#   u'and',
#   u'lsten',
#   u'to',
#   u'it',
#   u'its',
#   u'the',
#   u'easy',
#   u'way',
#   u'to',
#   u'find',
#   u'mistake',
#   u's\u2026',
#   u'\n'],
#  [u'virat',
#   u'kohli',
#   u'congratulate',
#   u'indian',
#   u'football',
#   u'team',
#   u'for',
#   u'beat',
#   u'afghanistan',
#   u'in',
#   u'saff',
#   u'daily',
#   u'news',
#   u'&amp',
#   u'analysis',
#   u'|',
#   u'\n'],
#  [u'get',
#   u'screen',
#   u'grab',
#   u'if',
#   u'it',
#   u'happen',
#   u' ',
#   u'google',
#   u'how',
#   u'to',
#   u'do',
#   u'assertion',
#   u'unsupported',
#   u'by',
#   u'fact',
#   u'do',
#   u'not',
#   u'help',
#   u'ur',
#   u'advocacy',
#   u'sot',
#   u'\U0001f1fa\U0001f1f8',
#   u'\n'],
#  [u'math', u'labyrinth', u'\n'],
#  [u'\n'],
#  [u'\n'],
#  [u'@tentardi',
#   u'can',
#   u'not',
#   u'search',
#   u'for',
#   u'it',
#   u'bc',
#   u'i',
#   u'do',
#   u'not',
#   u'have',
#   u'enough',
#   u'data',
#   u'plan',
#   u'for',
#   u'google',
#   u'in',
#   u'safari',
#   u'rn',
#   u'rip',
#   u'\n'],
#  [u'what',
#   u'be',
#   u'the',
#   u'best',
#   u'google',
#   u'adsense',
#   u'  ',
#   u'forums',
#   u'\n'],
#  [u'@yoboykaleb',
#   u'@nlgabe_',
#   u'lucked',
#   u'out',
#   u'with',
#   u'with',
#   u'find',
#   u'it',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'accident', u'254', u'peachtree', u'st', u'sw', u'@city', u'jail', u'\n'],
#  [u'rt',
# ...
#   u'deal',
#   u'\n'],
#  [u'the',
#   u'diary',
#   u'of',
#   u'a',
#   u'young',
#   u'girl',
#   u'anne',
#   u'frank',
#   u'now',
#   u'trend',
#   u'on',
#   u'google',
#   u'philippine',
#   u'search',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'go',
#   u'giant',
#   u'check',
#   u'late',
#   u'ny',
#   u'giant',
#   u'update',
#   u'via',
#   u'\n'],
#  [u'rt',
#   u'@h3bk11',
#   u'what',
#   u'it',
#   u'\u2019',
#   u'really',
#   u'like',
#   u'to',
#   u'work',
#   u'for',
#   u'a',
#   u'tech',
#   u'giant',
#   u'be',
#   u'sanfrancisco',
#   u'in',
#   u'siliconvalley?the',
#   u'answer',
#   u'be',
#   u'yes',
#   u' ',
#   u'\n'],
#  [u'what',
#   u'motivate',
#   u'us',
#   u'to',
#   u'want',
#   u'unusual',
#   u'pet',
#   u'news',
#   u'kamloops',
#   u'blog',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'mominul199',
#   u'sam___hurley',
#   u'google',
#   u'penalty',
#   u'recovery',
#   u'guide',
#   u'for',
#   u'execs',
#   u'free',
#   u'ebook',
#   u'guide',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'if', u'u', u'need', u'this', u'the', u'fbeye', u'lol', u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'rt',
#   u'@jackgilinsky',
#   u'i',
#   u'be',
#   u'lay',
#   u'naked',
#   u'outside',
#   u'&amp',
#   u'i',
#   u'just',
#   u'think',
#   u'to',
#   u'myself',
#   u'what',
#   u'if',
#   u'google',
#   u'map',
#   u'be',
#   u'take',
#   u'their',
#   u'annual',
#   u'satellite',
#   u'picture',
#   u'right',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'buy',
#   u'usa',
#   u'instagram',
#   u'follower',
#   u'buy',
#   u'website',
#   u'traffic',
#   u'with',
#   u'verify',
#   u'google',
#   u'analytics',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'the', u'sun', u'on', u'4', u'january', u'2016', u'sun', u' ', u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'today',
#   u'google',
#   u'suggest',
#   u'i',
#   u'search',
#   u'for',
#   u'image',
#   u'of',
#   u'\n'],
#  [u'@katyperry',
#   u"'s",
#   u'twin',
#   u'@carlythekatycat',
#   u'be',
#   u'all',
#   u'that',
#   u'come',
#   u'up',
#   u'\n'],
#  [u'@pdhana',
#   u'@bkdoss',
#   u'@psrajarajan',
#   u'@plk_raja',
#   u'google',
#   u'itself',
#   u'be',
#   u'make',
#   u'comedy',
#   u'ev',
#   u'ramasamy',
#   u'naaickar',
#   u'\U0001f61b\U0001f61c\U0001f600',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'@wedodumbthing',
#   u'@thenamesyousef',
#   u'@acaiabrese',
#   u'i',
#   u'try',
#   u'just',
#   u'google',
#   u'the',
#   u'one',
#   u'that',
#   u'be',
#   u'not',
#   u'filler',
#   u'it',
#   u'just',
#   u'be',
#   u'not',
#   u'for',
#   u'me',
#   u'i',
#   u'get',
#   u'to',
#   u'ep',
#   u'200',
#   u'lol',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'helps',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panels',
#   u'be',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'rt',
#   u'@paperphotoyo',
#   u'just',
#   u'have',
#   u'to',
#   u'google',
#   u'synonyms',
#   u'for',
#   u'the',
#   u'word',
#   u'creative',
#   u'\n'],
#  [u'\n'],
#  [u'the', u'irony', u'be', u'not', u'lose', u'on', u'me', u'\n'],
#  [u'rt',
#   u'@arzaylea',
#   u'@sweetiieslrh',
#   u'google',
#   u'instagram',
#   u'bio',
#   u'space',
#   u'and',
#   u'it',
#   u'will',
#   u'let',
#   u'you',
#   u'copy',
#   u'and',
#   u'paste',
#   u'it',
#   u'\n'],
#  [u'bracket',
#   u'update',
#   u'changed',
#   u'sizing',
#   u'to',
#   u'make',
#   u'reading',
#   u'easy',
#   u'\n'],
#  [u'@mariahjordan9',
#   u'at',
#   u'least',
#   u'google',
#   u'be',
#   u'try',
#   u'to',
#   u'say',
#   u'a',
#   u'life',
#   u'\n'],
#  [u'what',
#   u'self',
#   u'fix',
#   u'negativity.1',
#   u'occur',
#   u'google',
#   u'present',
#   u'time',
#   u'40',
#   u'day',
#   u'my',
#   u'recondite',
#   u'automation',
#   u'lickspit',
#   u'opmg',
#   u'\n'],
#  [u'google', u'cultural', u'institute', u'\n'],
#  [u'create',
#   u'your',
#   u'own',
#   u'gallery',
#   u'and',
#   u'share',
#   u'favourite',
#   u'find',
#   u'with',
#   u'friend',
#   u'\n'],
#  [u'\n'],
#  [u'i',
#   u'be',
#   u'now',
#   u'a',
#   u'd',
#   u'list',
#   u'celebrity',
#   u'in',
#   u'kim',
#   u'kardashian',
#   u'hollywood',
#   u'you',
#   u'can',
#   u'be',
#   u'famous',
#   u'too',
#   u'by',
#   u'play',
#   u'on',
#   u'android',
#   u'\n'],
#  [u'love',
#   u'this',
#   u'check',
#   u'out',
#   u'all',
#   u'for',
#   u'one',
#   u'by',
#   u'five',
#   u'for',
#   u'fight',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@nadimah1505', u'here', u'you', u'go', u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https:\u2026',
#   u'\n'],
#  [u'if',
#   u'interest',
#   u'in',
#   u'help',
#   u'test',
#   u'mazevr',
#   u'for',
#   u'google',
#   u'cardboard',
#   u'on',
#   u'iphone',
#   u'5',
#   u'or',
#   u'6',
#   u'dm',
#   u'your',
#   u'email',
#   u'address',
#   u'testflight',
#   u'require',
#   u'it',
#   u'thanks',
#   u'\n'],
#  [u'broker',
#   u'the',
#   u'premium',
#   u'domain',
#   u'interested',
#   u'@aol',
#   u'@comcast',
#   u'@google',
#   u'@yahoo',
#   u'@b',
#   u'@msn',
#   u'@microsoft',
#   u'\n'],
#  [u'rt',
#   u'@im__joshi',
#   u'@pdhana',
#   u'@bkdos',
#   u'@psrajarajan',
#   u'@plk_raja',
#   u'google',
#   u'itself',
#   u'be',
#   u'make',
#   u'comedy',
#   u'ev',
#   u'ramasamy',
#   u'naaickar',
#   u'\U0001f61b\U0001f61c\U0001f600',
#   u'\n'],
#  [u'i',
#   u'like',
#   u'a',
#   u'@youtube',
#   u'video',
#   u'10',
#   u'thing',
#   u'you',
#   u'should',
#   u'never',
#   u'google',
#   u'warning',
#   u'gross',
#   u'\n'],
#  [u'rt',
#   u'@eastridgeibl',
#   u'week',
#   u'2',
#   u'power',
#   u'rankings\U0001f608',
#   u'\n'],
#  [u'sometimes',
#   u'i',
#   u'google',
#   u'cute',
#   u'way',
#   u'to',
#   u'ask',
#   u'someone',
#   u'out',
#   u'cause',
#   u'my',
#   u'idea',
#   u'suck',
#   u'asf',
#   u'\n'],
#  [u'sb',
#   u'nation',
#   u'colt',
#   u'vs.',
#   u'titans',
#   u'final',
#   u'score',
#   u'colts',
#   u'beat',
#   u'titans',
#   u'30',
#   u'24',
#   u'in',
#   u'what',
#   u'be',
#   u'likely',
#   u'chuck',
#   u'pagano',
#   u"'s",
#   u'final',
#   u'game',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'rt', u'@lovelife201114', u'makingamurderer', u'@helpstevenavery', u'\n'],
#  [u'\n'],
#  [u'one',
#   u'can',
#   u'leave',
#   u'the',
#   u'sherifs',
#   u'office',
#   u'comment',
#   u'via',
#   u'google',
#   u'map',
#   u'\n'],
#  [u'i',
#   u'be',
#   u'not',
#   u'sure',
#   u'what',
#   u'you',
#   u'mean',
#   u'what',
#   u'sort',
#   u'of',
#   u'question',
#   u'i',
#   u'like',
#   u'stikman',
#   u'google',
#   u'him',
#   u'if',
#   u'you',
#   u'have',
#   u'question',
#   u'know',
#   u'a',
#   u'ton',
#   u'\n'],
#  [u'google', u'answer', u'your', u'question', u'\n'],
#  [u'larrypage', u'answer', u'the', u'fundamental', u'question', u'\n'],
#  [u'mondaymotivation', u'quote', u'\n'],
#  [u'agoa',
#   u'trade',
#   u'stand',
#   u'off',
#   u'tie',
#   u'between',
#   u'sa',
#   u'us',
#   u'in',
#   u'jeopardy',
#   u'|',
#   u'enca',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@jasondemanzo',
#   u'it',
#   u'will',
#   u'give',
#   u'you',
#   u'something',
#   u'to',
#   u'google',
#   u'since',
#   u'you',
#   u'think',
#   u'you',
#   u'know',
#   u'so',
#   u'much',
#   u'\n'],
#  [u'try',
#   u'to',
#   u'find',
#   u'bootleg',
#   u'version',
#   u'of',
#   u'tfa',
#   u'on',
#   u'google',
#   u'\n'],
#  [u'the',
#   u'best',
#   u'advice',
#   u'i',
#   u'have',
#   u'ever',
#   u'receive',
#   u'from',
#   u'google',
#   u'how',
#   u'to',
#   u'numb',
#   u'emotional',
#   u'pain',
#   u'\n'],
#  [u'thanks',
#   u'for',
#   u'follow',
#   u'@egibis_blog',
#   u'look',
#   u'for',
#   u'me',
#   u'on',
#   u'fb',
#   u'google+',
#   u'linkedin',
#   u'&amp',
#   u'pinterest',
#   u'under',
#   u'trucrowd',
#   u'see',
#   u'ya',
#   u'there',
#   u'\n'],
#  [u'eco', u'302', u'week', u'3', u'quiz', u'strayer-', u'\n'],
#  [u'7',
#   u'a33',
#   u'google',
#   u'android',
#   u'4.4',
#   u'quad',
#   u'core',
#   u'dual',
#   u'camera',
#   u'8gb',
#   u'tablet',
#   u'pc',
#   u'wifi',
#   u'bluetooth',
#   u'bid',
#   u'now',
#   u'on\u2026',
#   u'\n'],
#  [u'google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panel',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'google',
#   u'to',
#   u'analyze',
#   u'if',
#   u'rooftop',
#   u'solar',
#   u'panel',
#   u'be',
#   u'a',
#   u'good',
#   u'deal',
#   u'\n'],
#  [u'@wisdom_star',
#   u'summary',
#   u'of',
#   u'the',
#   u'rise',
#   u'of',
#   u'hate',
#   u'search',
#   u'wisdomstarsnews',
#   u'hatecrimes',
#   u'google',
#   u'terrorism',
#   u'parisattacks',
#   u'\n'],
#  [u'reliable',
#   u'seattle',
#   u'town',
#   u'car',
#   u'hire',
#   u'service',
#   u'.for',
#   u'more',
#   u'information',
#   u'click',
#   u'on',
#   u'this',
#   u'link',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'listen',
#   u'to',
#   u'something',
#   u'you',
#   u'forgot',
#   u'carter',
#   u'3',
#   u'by',
#   u'lil',
#   u'wanye',
#   u'|',
#   u'\n'],
#  [u'rt',
#   u'@dave_ri',
#   u'top',
#   u'10',
#   u'google',
#   u'docs',
#   u'posts',
#   u'of',
#   u'2015',
#   u'via',
#   u'@alicekeeler',
#   u'edtech',
#   u'\n'],
#  [u'@poptivist',
#   u'@buttercupcas',
#   u'here',
#   u'you',
#   u'go',
#   u'i',
#   u'hope',
#   u'it',
#   u'works',
#   u'\n'],
#  [u'google', u' ', u'\n'],
#  [u'the',
#   u'associated',
#   u'press',
#   u'steelers',
#   u'sneak',
#   u'into',
#   u'afc',
#   u'playoff',
#   u'with',
#   u'28',
#   u'12',
#   u'win',
#   u'over',
#   u'browns',
#   u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'would',
#   u'your',
#   u'company',
#   u'benefit',
#   u'from',
#   u'a',
#   u'tailored',
#   u'google',
#   u'&amp',
#   u'socialmedia',
#   u'seminar',
#   u'0161',
#   u'432',
#   u'7268',
#   u'https:\u2026',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'saw',
#   u'this..thank',
#   u'you',
#   u'for',
#   u'share',
#   u'it',
#   u'\n'],
#  [u'waka',
#   u'flocka',
#   u'&amp',
#   u'young',
#   u'sizzle',
#   u'new',
#   u'year',
#   u'prod',
#   u'by',
#   u'luke',
#   u'\n'],
#  [u'@jeremylawrencee',
#   u'ya',
#   u'fios',
#   u'here',
#   u'at',
#   u'my',
#   u'place',
#   u'and',
#   u'at',
#   u'my',
#   u'parent',
#   u'hopefully',
#   u'we',
#   u'get',
#   u'google',
#   u'fiber',
#   u'here',
#   u'\n'],
#  [u'spyhuman',
#   u'be',
#   u'mobile',
#   u'track',
#   u'application',
#   u'gp',
#   u' ',
#   u'call',
#   u'log',
#   u'call',
#   u'record',
#   u'\n'],
#  [u'\n'],
#  [u'so',
#   u'thankful',
#   u'for',
#   u'the',
#   u'google',
#   u'chromecast',
#   u'let',
#   u'me',
#   u'stream',
#   u'music',
#   u'from',
#   u'my',
#   u'phone',
#   u'to',
#   u'my',
#   u'tv\U0001f64f\U0001f64f\U0001f64f\U0001f64f',
#   u'\n'],
#  [u'rt',
#   u'@googleexpertuk',
#   u'google',
#   u'support',
#   u'swedish',
#   u'chef',
#   u'from',
#   u'the',
#   u'muppets',
#   u'@muppetsstudio',
#   u'internet',
#   u'technology',
#   u'\n'],
#  [u'rt',
#   u'@lovingianni',
#   u'come',
#   u'at',
#   u'me',
#   u'with',
#   u'something',
#   u'that',
#   u"'",
#   u' ',
#   u'grammatically',
#   u'incorrect',
#   u'i',
#   u'be',
#   u'fire',
#   u'yo',
#   u'as',
#   u'up',
#   u'with',
#   u'word',
#   u'you',
#   u'go',
#   u'have',
#   u'to',
#   u'google',
#   u'\n'],
#  [u'how', u'to', u'use', u'google', u'effectively', u'\n'],
#  [u'rt',
#   u'@wmsolomon',
#   u'do',
#   u'not',
#   u'use',
#   u'google',
#   u'for',
#   u'your',
#   u'research',
#   u'just',
#   u'read',
#   u'history',
#   u'it',
#   u"'",
#   u'fun',
#   u'educate',
#   u'&amp',
#   u'relevant',
#   u'in',
#   u'a',
#   u'funny',
#   u'way',
#   u'history',
#   u'keep',
#   u'repeatin\u2026',
#   u'\n'],
#  [u'socialmediatips',
#   u'powerful',
#   u'personal',
#   u'branding',
#   u'tips',
#   u'to',
#   u'take',
#   u'you',
#   u'from',
#   u'digital',
#   u'zero',
#   u'+smm\u21achttps://t.co/2doa1wscru',
#   u'\n'],
#  [u'socialmediatips',
#   u'powerful',
#   u'personal',
#   u'branding',
#   u'tips',
#   u'to',
#   u'take',
#   u'you',
#   u'from',
#   u'digital',
#   u'zero',
#   u'+smm\u21achttps://t.co/vnedwwkkhb',
#   u'\n'],
#  [u'sometimes',
#   u'i',
#   u'call',
#   u'303',
#   u'499',
#   u'7111',
#   u'and',
#   u'listen',
#   u'to',
#   u'the',
#   u'atomic',
#   u'clock',
#   u'at',
#   u'nist',
#   u'tick',
#   u'off',
#   u'second',
#   u'at',
#   u'the',
#   u'tone',
#   u'5:44',
#   u'utc',
#   u'\n'],
#  [u'microsoft',
#   u'will',
#   u'inform',
#   u'you',
#   u'if',
#   u'government',
#   u'be',
#   u'spy',
#   u'on',
#   u'you',
#   u'\n'],
#  [u'@mesipisu', u'new', u'video', u'alert', u'\n'],
#  [u'rt',
#   u'@surajravifan',
#   u'miruthantrailer',
#   u'rock',
#   u'@youtube',
#   u'with',
#   u'6',
#   u'lakhs+',
#   u'view',
#   u'&amp',
#   u'8k+',
#   u'likes',
#   u'@actor_jayamravi',
#   u'@shaktirajan',
#   u'therihit',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'zaker',
#   u'pro',
#   u'azkar',
#   u'muslim',
#   u'pray',
#   u'android',
#   u'apps',
#   u'on',
#   u'google',
#   u'play',
#   u'\n'],
#  [u'write',
#   u'an',
#   u'android',
#   u'application',
#   u' ',
#   u'by',
#   u'patilvaibhavp99',
#   u'i',
#   u'want',
#   u'to',
#   u'integrate',
#   u'google',
#   u'auto',
#   u'complete',
#   u'place',
#   u' ',
#   u'api',
#   u'in',
#   u'android',
#   u'ap\u2026',
#   u'\n'],
#  [u'.@sardesairajdeep',
#   u'it',
#   u'take',
#   u'58',
#   u'minute',
#   u'now',
#   u'as',
#   u'per',
#   u'google',
#   u'map',
#   u'unless',
#   u'of',
#   u'course',
#   u'google',
#   u'be',
#   u'a',
#   u'modi',
#   u'agent',
#   u'\n'],
#  [u'universo',
#   u'nokia',
#   u'newsspot',
#   u'google',
#   u'reader',
#   u'potente',
#   u'e',
#   u'versatile',
#   u'\n'],
#  [u'rt',
#   u'@koderedapp',
#   u'check',
#   u'out',
#   u'our',
#   u'new',
#   u'android',
#   u'game',
#   u'roadrage',
#   u'endless',
#   u'free',
#   u'addictive',
#   u'shooter',
#   u'racing',
#   u'rocket',
#   u'b\u2026',
#   u'\n'],
#  [u'rt',
#   u'@bella230893',
#   u'preview',
#   u'bestplan',
#   u'calendar',
#   u'by',
#   u'@planbap',
#   u'\n'],
#  [u'to',
#   u'order',
#   u'please',
#   u'refer',
#   u'here',
#   u'\U0001f447\U0001f3fb(malaysia',
#   u'go',
#   u'\n'],
#  [u'1451886241-weekly',
#   u'european',
#   u'tour',
#   u'fantasy',
#   u'golf',
#   u'app',
#   u'for',
#   u'android',
#   u'\n'],
#  [u'the',
#   u'associated',
#   u'press',
#   u'viking',
#   u'take',
#   u'nfc',
#   u'north',
#   u'hold',
#   u'on',
#   u'to',
#   u'beat',
#   u'packer',
#   u'20',
#   u'13',
#   u'\n'],
#  [u'king',
#   u'of',
#   u'dark',
#   u'fantasy',
#   u'summon',
#   u'today',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  [u'@emmaajoyce',
#   u'@chichenry',
#   u'i',
#   u'look',
#   u'it',
#   u'up',
#   u'on',
#   u'google',
#   u'and',
#   u'it',
#   u'give',
#   u'me',
#   u'nothing',
#   u'\n'],
#  [u'i',
#   u'just',
#   u'receive',
#   u'a',
#   u'reward',
#   u'legendary',
#   u'island',
#   u'android',
#   u'gameinsight',
#   u'androidgames',
#   u'\n'],
#  [u'new',
#   u'event',
#   u'now',
#   u'on',
#   u'get',
#   u'new',
#   u'rank',
#   u's',
#   u'monsters',
#   u'app',
#   u'store',
#   u'google',
#   u'play',
#   u'darksummoner',
#   u'\n'],
#  ...]

# %%
def lemmalize(sentence):
    result = english_parser(sentence)
    for (i, word) in enumerate(result): 
        print word
        if (word != word.lemma):
            final.append(word.lemma)
        else:
            final.append(word)
        print "\tParent: {}".format(word.head.lemma_)
        print "\tPhrase type: {}".format(word.dep_)
        print "\tKnown entity type: {}".format(word.ent_type_ if word.ent_type_ else 'n/a')
        print "\tLemma: {}".format(word.lemma_)
# Out:
# u'I made a(n) Small Tourmaline in Paradise Island! https://t.co/'

# %% [markdown]
# ## Exercise 1c
#
# Write a function that can take a sentence parsed by `spacy`
# and return the verbs of the sentence (preferably lemmatized)

# %%
def get_actions(parsed):
    actions = []
    # Your code here
    return actions

# %% [markdown]
# ## Exercise 1d
# For each tweet, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb. You'll need to use your `mentions_company` and `get_actions` functions.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %% [markdown]
# ## Exercise 1e
# Write a function that identifies countries - HINT: the entity label for countries is GPE (or GeoPolitical Entity)

# %%
def mentions_country(parsed, country):
    pass

# %% [markdown]
# ## Exercise 1f
#
# Re-run (d) to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %% [markdown]
# ## Exercise 2
# Build a `word2vec` model of the tweets we have collected using `gensim`.
#
# ### Exercise 2a:
# First take the collection of tweets and tokenize them using spacy.
#
# * Think about how this should be done.
# * Should you only use upper-case or lower-case?
# * Should you remove punctuations or symbols?

# %%
text_split = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                for x in nlp_toolkit(t)] for t in tweets]

# %% [markdown]
# ### Exercise 2b:
# Build a `word2vec` model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
model = Word2Vec(text_split, size=100, window=4, min_count=5, workers=4)

# %% [markdown]
# ### Exercise 2c:
# Test your word2vec model with a few similarity functions.
# * Find words similar to 'Syria'.
# * Find words similar to 'war'.
# * Find words similar to "Iran".
# * Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['Syria'])

# %% [markdown]
# # Exercise 2d
#
# Adjust the choices / parameters in (b) and (c) as necessary.

# %% [markdown]
# ## Exercise 3
#
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.
# * Do this using just spacy.
# * Do this using word2vec similarity scores.

# %%
# Using spacy
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %%
# Using word2vec similarity scores
for tweet in tweets[:200]:
    parsed = nlp_toolkit(tweet)
    pass
